# %% [markdown]
# # **Starting to Crawl**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen("https://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html)
for link in bsObj.findAll("a"):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(film)
# /wiki/Tremors_(film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Personal_life
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Awards_and_nominations
# #Honors
# #Accolades
# #Filmography
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# #cite_note-32
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# /wiki/Tremors_(film)
# #cite_note-39
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# #cite_note-40
# #cite_note-41
# /wiki/Egg_as_food
# #cite_note-42
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-43
# /wiki/Tracy_Pollan
# #cite_note-44
# #cite_note-45
# #cite_note-46
# /wiki/The_Times
# #cite_note-47
# #cite_note-48
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-49
# #cite_note-50
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-51
# #cite_note-52
# #cite_note-53
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# #cite_note-54
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# #cite_note-55
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-56
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# #cite_note-57
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources
# //www.google.com/search?as_eq=wikipedia&q=%22Kevin+Bacon%22
# //www.google.com/search?tbm=nws&q=%22Kevin+Bacon%22+-wikipedia
# //www.google.com/search?&q=%22Kevin+Bacon%22+site:news.google.com/newspapers&source=newspapers
# //www.google.com/search?tbs=bks:1&q=%22Kevin+Bacon%22+-wikipedia
# //scholar.google.com/scholar?q=%22Kevin+Bacon%22
# https://www.jstor.org/action/doBasicSearch?Query=%22Kevin+Bacon%22&acc=on&wc=on
# /wiki/Help:Maintenance_template_removal
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-58
# /wiki/Denver_Film_Festival
# #cite_note-59
# /wiki/Phoenix_Film_Festival
# #cite_note-60
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-61
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-62
# /wiki/Seattle_International_Film_Festival
# #cite_note-63
# #cite_note-64
# /wiki/Apollo_13_(film)
# #cite_note-65
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-66
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-67
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# http://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-44
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-45
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-46
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-47
# #cite_ref-48
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_49-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-50
# #cite_ref-51
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-52
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-53
# http://www.drawtheline.org/sign-now/
# #cite_ref-54
# http://www.sixdegrees.org/
# #cite_ref-55
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-56
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-57
# http://baconbros.com/
# #cite_ref-58
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-59
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-60
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-61
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-62
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-63
# https://www.imdb.com/event/ev0000600/2015/1/
# #cite_ref-64
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-65
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-66
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-67
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q89627521#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Template:GoldenGlobeBestActorTVMiniseriesFilm
# /wiki/Template_talk:GoldenGlobeBestActorTVMiniseriesFilm
# https://en.wikipedia.org/w/index.php?title=Template:GoldenGlobeBestActorTVMiniseriesFilm&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=948878543
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:BLP_articles_lacking_sources_from_October_2017
# /wiki/Category:All_BLP_articles_lacking_sources
# /wiki/Category:Commons_category_link_is_the_pagename
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_not_in_Wikidata
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Wikipedia:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=948878543
# /w/index.php?title=Kevin_Bacon&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=948878543&wpFormIdentifier=titleform
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=Kevin+Bacon
# /w/index.php?title=Special:ElectronPdf&page=Kevin+Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# # **Retrieve Desired Article**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import re
html = urlopen("https://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html)
for link in bsObj.find("div", {"id":"bodyContent"}).findAll("a",href=re.compile("^(/wiki/)((?!:).)*$")):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(film)
# /wiki/Tremors_(film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(film)
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# /wiki/Egg_as_food
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Lortel_Archives
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random

# %%
random.seed(datetime.datetime.now())
def getLinks(articleUrl):
  html = urlopen("http://en.wikipedia.org"+articleUrl)
  bsObj = BeautifulSoup(html)
  return bsObj.find("div",{"id":"bodyContent"}).findAll("a",href = re.compile("^(/wiki/)((?!:).)*$"))
links = getLinks("/wiki/Kevin_Bacon")
while len(links)>0:
  newArticle = links[random.randint(0,len(links)-1)].attrs["href"]
  print(newArticle)
  link = getLinks(newArticle)
# Out:
# /wiki/Wild_Things_(film)
# /wiki/Bryan_Cranston
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Access_Hollywood
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/Taking_Chance
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/David_Boreanaz
# /wiki/Daniel_Day-Lewis
# /wiki/Joaquin_Phoenix
# /wiki/Edmund_Bacon_(architect)
# /wiki/The_Following
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/IMDb
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Sean_Penn
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Following
# /wiki/Robert_Patrick
# /wiki/Christopher_Reeve
# /wiki/Lemon_Sky
# /wiki/Losing_Chase
# /wiki/Academy_Award
# /wiki/Charles_J._Cooper
# /wiki/Erd%C5%91s_number
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/United_Kingdom
# /wiki/Diner_(film)
# /wiki/Sam_Rockwell
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Jack_Nicholson
# /wiki/Screen_Actors_Guild_Award
# /wiki/Rachel_Blanchard
# /wiki/Mads_Mikkelsen
# /wiki/TV_Guide_Award
# /wiki/Wilshire_Ebell_Theatre
# /wiki/Geoffrey_Rush
# /wiki/Footloose_(1984_film)
# /wiki/Golden_Globe_Award
# /wiki/Russell_Crowe
# /wiki/Music_album
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Brian_Dennehy
# /wiki/Billy_Bob_Thornton
# /wiki/Primetime_Emmy_Award
# /wiki/Paul_Giamatti
# /wiki/Michael_Bacon_(musician)
# /wiki/Taking_Chance
# /wiki/Idris_Elba
# /wiki/Daniel_Stern_(actor)
# /wiki/Steven_Weber_(actor)
# /wiki/Screen_Actors_Guild_Award
# /wiki/Russell_Crowe
# /wiki/Ian_McKellen
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/The_New_York_Times
# /wiki/The_Austin_Chronicle
# /wiki/Saturn_Award
# /wiki/Proposition_8
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/William_H._Macy
# /wiki/Flatliners
# /wiki/Pyrates
# /wiki/MPAA_film_rating_system
# /wiki/The_Austin_Chronicle
# /wiki/Paul_Erd%C5%91s
# /wiki/Ben_Browder
# /wiki/Footloose_(1984_film)
# /wiki/Mystic_River_(film)
# /wiki/Tim_Daly
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Internet_Broadway_Database
# /wiki/Satellite_Awards
# /wiki/He_Said,_She_Said_(film)
# /wiki/Murder_in_the_First_(film)
# /wiki/Ponzi_scheme
# /wiki/Tracy_Pollan
# /wiki/Paul_Erd%C5%91s
# /wiki/AllMovie
# /wiki/Bryan_Cranston
# /wiki/The_Bacon_Brothers
# /wiki/Mickey_Rooney
# /wiki/Ghent_International_Film_Festival
# /wiki/Gary_Oldman
# /wiki/SixDegrees.org
# /wiki/The_Austin_Chronicle
# /wiki/Mystic_River_(film)
# /wiki/Russell_Crowe
# /wiki/Finding_Your_Roots
# /wiki/James_Dean
# /wiki/Kyle_Chandler
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/Bravo_Otto
# /wiki/Pyrates
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Andrew_Lincoln
# /wiki/Hollow_Man
# /wiki/Michael_Strobl
# /wiki/MPAA_film_rating_system
# /wiki/Russell_Crowe
# /wiki/Colin_Firth
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/Daniel_Day-Lewis
# /wiki/SixDegrees.org
# /wiki/Tracy_Pollan
# /wiki/Sean_Penn
# /wiki/Phoenix_Film_Festival
# /wiki/Frost/Nixon_(film)
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Andrew_Lincoln
# /wiki/EE_(telecommunications_company)
# /wiki/James_Woods
# /wiki/Losing_Chase
# /wiki/Gary_Sinise
# /wiki/Russell_Crowe
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Val_Kilmer
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/James_Woods
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Michael_Keaton
# /wiki/Barry_Levinson
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Bill_Nighy
# /wiki/Elizabeth_Perkins
# /wiki/George_Clooney
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Austin_Chronicle
# /wiki/Michael_Strobl
# /wiki/Blockbuster_(entertainment)
# /wiki/Black_Mass_(film)
# /wiki/I_Love_Dick_(TV_series)
# /wiki/George_Clooney
# /wiki/Wild_Things_(film)
# /wiki/Kevin_Costner
# /wiki/Big_screen
# /wiki/Kyle_MacLachlan
# /wiki/Second_Stage_Theatre
# /wiki/Bravo_Otto
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Apollo_13_(film)
# /wiki/Flatliners
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Murder_in_the_First_(film)
# /wiki/Ben_Kingsley
# /wiki/Steve_Guttenberg
# /wiki/Brian_Dennehy
# /wiki/Teen_Choice_Awards
# /wiki/Trivia
# /wiki/She%27s_Having_a_Baby
# /wiki/Perry_v._Brown
# /wiki/Hollow_Man
# /wiki/The_Woodsman_(2004_film)
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Chlotrudis_Awards
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Manhattan
# /wiki/Mickey_Rourke
# /wiki/Apollo_13_(film)
# /wiki/Paul_Giamatti
# /wiki/Michael_Caine
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Flux
# /wiki/A_Few_Good_Men
# /wiki/Paul_Giamatti
# /wiki/Flatliners
# /wiki/Access_Hollywood
# /wiki/She%27s_Having_a_Baby
# /wiki/Sam_Heughan
# /wiki/Hollywood_Walk_of_Fame
# /wiki/The_Woodsman_(2004_film)
# /wiki/Andrew_Lincoln
# /wiki/The_Following
# /wiki/Flux
# /wiki/Manhattan
# /wiki/Erd%C5%91s_number
# /wiki/Ghent_International_Film_Festival
# /wiki/Daniel_Stern_(actor)
# /wiki/Kyra_Sedgwick
# /wiki/Bryan_Cranston
# /wiki/Hollow_Man
# /wiki/Losing_Chase
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tom_Hiddleston
# /wiki/Mickey_Rourke
# /wiki/Tim_Robbins
# /wiki/The_Following
# /wiki/Michael_Caine
# /wiki/Forty_Deuce
# /wiki/Robert_Patrick
# /wiki/Russell_Crowe
# /wiki/Michael_Douglas
# /wiki/James_Garner
# /wiki/Kevin_Costner
# /wiki/Kevin_Bacon_filmography
# /wiki/Giffoni_Film_Festival
# /wiki/Kyle_Chandler
# /wiki/Russell_Crowe
# /wiki/Paul_Erd%C5%91s
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/A_Few_Good_Men_(film)
# /wiki/Paul_Verhoeven
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Apollo_13_(film)
# /wiki/Bacon_number
# /wiki/Gary_Sinise
# /wiki/Matthew_Fox
# /wiki/Paul_Giamatti
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Bucknell_University
# /wiki/Screen_Actors_Guild_Award
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Andrew_Lincoln
# /wiki/Mark_Ruffalo
# /wiki/Paul_Verhoeven
# /wiki/Mickey_Rooney
# /wiki/Footloose_(1984_film)
# /wiki/Leonardo_DiCaprio
# /wiki/Kevin_Costner
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/Darren_Criss
# /wiki/Daniel_Day-Lewis
# /wiki/Social_networks
# /wiki/Kyle_MacLachlan
# /wiki/The_Woodsman_(2004_film)
# /wiki/The_Following
# /wiki/Taking_Chance
# /wiki/Rebel_Without_a_Cause
# /wiki/Gary_Sinise
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Hollow_Man
# /wiki/Ben_Kingsley
# /wiki/James_Dean
# /wiki/Billy_Bob_Thornton
# /wiki/Josh_Holloway
# /wiki/Perry_v._Brown
# /wiki/The_Woodsman_(2004_film)
# /wiki/Dustin_Lance_Black
# /wiki/The_Woodsman_(2004_film)
# /wiki/Bacon_number
# /wiki/Primetime_Emmy_Award
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Ben_Browder
# /wiki/Mystic_River_(film)
# /wiki/The_Following
# /wiki/Taking_Chance
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Paul_Newman
# /wiki/Stir_of_Echoes
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Desert_Storm
# /wiki/Losing_Chase
# /wiki/Rachel_Blanchard
# /wiki/MPAA
# /wiki/Payola
# /wiki/Flatliners
# /wiki/Barry_Levinson
# /wiki/Screen_Actors_Guild_Award
# /wiki/Andrew_Lincoln
# /wiki/Satellite_Awards
# /wiki/Kevin_Costner
# /wiki/Jim_Broadbent
# /wiki/Bacon_number
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Mystic_River_(film)
# /wiki/Kyle_MacLachlan
# /wiki/Jack_Lemmon
# /wiki/Rachel_Blanchard
# /wiki/Taking_Chance
# /wiki/Flux
# /wiki/Footloose_(1984_film)
# /wiki/Sam_Rockwell
# /wiki/The_Woodsman_(2004_film)
# /wiki/Tremors_(film)
# /wiki/Philip_Seymour_Hoffman
# /wiki/Jim_Broadbent
# /wiki/Rachel_Blanchard
# /wiki/Ben_Kingsley
# /wiki/Bacon_number
# /wiki/Guiding_Light
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Kyle_Chandler
# /wiki/Bacon_number
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Michael_C._Hall
# /wiki/Footloose_(1984_film)
# /wiki/Al_Pacino
# /wiki/Giffoni_Film_Festival
# /wiki/Julia_R._Masterman_High_School
# /wiki/The_River_Wild
# /wiki/Sosie_Bacon
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Footloose_(1984_film)
# /wiki/Dustin_Hoffman
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/A_Few_Good_Men
# /wiki/TV_Guide_Award
# /wiki/Daniel_Day-Lewis
# /wiki/Tremors_(film)
# /wiki/Sam_Heughan
# /wiki/Michael_Bacon_(musician)
# /wiki/Sosie_Bacon
# /wiki/The_Woodsman_(2004_film)
# /wiki/Oscar_Isaac
# /wiki/Al_Pacino
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/John_Hughes_(filmmaker)
# /wiki/Stacy_Keach
# /wiki/The_Times
# /wiki/Loverboy_(2005_film)
# /wiki/MPAA_film_rating_system
# /wiki/Nancy_Mills
# /wiki/Pedophile
# /wiki/Academy_Award
# /wiki/Mickey_Rooney
# /wiki/Oliver_Stone
# /wiki/Footloose_(1984_film)
# /wiki/Golden_Globe_Award
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Jack_Nicholson
# /wiki/TV_Guide_Award
# /wiki/Rachel_Blanchard
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Kyra_Sedgwick
# /wiki/8_(play)
# /wiki/Frost/Nixon_(film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Kevin_Bacon_filmography
# /wiki/Darren_Criss
# /wiki/Ted_Danson
# /wiki/Diner_(film)
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Alan_Rickman
# /wiki/Taking_Chance
# /wiki/Patriots_Day_(film)
# /wiki/Animal_House
# /wiki/Screen_Actors_Guild_Award
# /wiki/Daniel_Day-Lewis
# /wiki/Kyra_Sedgwick
# /wiki/Giffoni_Film_Festival
# /wiki/Colin_Firth
# /wiki/The_Following
# /wiki/Kevin_Costner
# /wiki/Kevin_Costner
# /wiki/Kevin_Costner
# /wiki/Ponzi_scheme
# /wiki/Joaquin_Phoenix
# /wiki/Diner_(film)
# /wiki/Ben_Browder
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Gary_Sinise
# /wiki/Joel_Schumacher
# /wiki/The_Following
# /wiki/Gary_Oldman
# /wiki/Obie_Award
# /wiki/Mads_Mikkelsen
# /wiki/Taking_Chance
# /wiki/Jeff_Bridges
# /wiki/Daniel_Day-Lewis
# /wiki/Rachel_Blanchard
# /wiki/Jeremy_Irons
# /wiki/Hollow_Man
# /wiki/Chlotrudis_Awards
# /wiki/Mystic_River_(film)
# /wiki/James_Garner
# /wiki/Proposition_8
# /wiki/The_Following
# /wiki/Bacon_number
# /wiki/The_Big_Picture_(1989_film)
# /wiki/James_Dean
# /wiki/Andrew_Lincoln
# /wiki/TV_Guide_Award
# /wiki/Al_Pacino
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/Taking_Chance
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Andrew_Lincoln
# /wiki/SixDegrees.org
# /wiki/HBO
# /wiki/Paul_Giamatti
# /wiki/Mickey_Rooney
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Mystic_River_(film)
# /wiki/Colin_Firth
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Perry_v._Brown
# /wiki/IMDb
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/The_Following
# /wiki/Manhattan
# /wiki/Loverboy_(2005_film)
# /wiki/Paul_Newman
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Big_screen
# /wiki/Saturn_Award
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Mads_Mikkelsen
# /wiki/Andrew_Lincoln
# /wiki/Lortel_Archives
# /wiki/Michael_C._Hall
# /wiki/Kyle_MacLachlan
# /wiki/Raul_Julia
# /wiki/Music_album
# /wiki/MPAA
# /wiki/Forest_Whitaker
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Al_Pacino
# /wiki/Christopher_Reeve
# /wiki/Bryan_Cranston
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Jack_Lemmon
# /wiki/Sosie_Bacon
# /wiki/TV_Guide_Award
# /wiki/Michael_Douglas
# /wiki/Will.i.am
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Flatliners
# /wiki/Circle_in_the_Square
# /wiki/Academy_Award
# /wiki/Idris_Elba
# /wiki/Jim_Broadbent
# /wiki/Jeff_Bridges
# /wiki/Taking_Chance
# /wiki/Sleepers_(film)
# /wiki/Egg_as_food
# /wiki/Idris_Elba
# /wiki/Mystic_River_(film)
# /wiki/Sean_Penn
# /wiki/Where_the_Truth_Lies
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/Edmund_Bacon_(architect)
# /wiki/Kevin_Bacon_filmography
# /wiki/Geoffrey_Rush
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Footloose_(1984_film)
# /wiki/Bruce_Campbell
# /wiki/Teen_Choice_Awards
# /wiki/SixDegrees.org
# /wiki/Bryan_Cranston
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Social_networks
# /wiki/Steve_Guttenberg
# /wiki/Alan_Rickman
# /wiki/Mystic_River_(film)
# /wiki/Kyra_Sedgwick
# /wiki/Idris_Elba
# /wiki/Payola
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/8_(play)
# /wiki/Diner_(film)
# /wiki/Philadelphia
# /wiki/Beau_Bridges
# /wiki/Michael_Douglas
# /wiki/Darren_Criss
# /wiki/Robert_Duvall
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/The_New_York_Times
# /wiki/Broadcast_Film_Critics_Association
# /wiki/The_Following
# /wiki/The_Following
# /wiki/Michael_Douglas
# /wiki/Sam_Rockwell
# /wiki/Mystic_River_(film)
# /wiki/Mystic_River_(film)
# /wiki/Rachel_Blanchard
# /wiki/Scream_Awards
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Where_the_Truth_Lies
# /wiki/SixDegrees.org
# /wiki/David_Boreanaz
# /wiki/Hollow_Man
# /wiki/Josh_Holloway
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Egg_as_food
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/George_Clooney
# /wiki/Obie_Award
# /wiki/Andrew_Lincoln
# /wiki/Ghent_International_Film_Festival
# /wiki/Dustin_Hoffman
# /wiki/James_Garner
# /wiki/Jeff_Bridges
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Idris_Elba
# /wiki/Colin_Firth
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Bernie_Madoff
# /wiki/Richard_Dean_Anderson
# /wiki/Mickey_Rourke
# /wiki/IMDb
# /wiki/Edmund_Bacon_(architect)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Giffoni_Film_Festival
# /wiki/The_River_Wild
# /wiki/Mystic_River_(film)
# /wiki/AllMovie
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Murder_in_the_First_(film)
# /wiki/Jim_Broadbent
# /wiki/Gary_Sinise
# /wiki/Forty_Deuce
# /wiki/Casey_Affleck
# /wiki/Brian_Dennehy
# /wiki/Darren_Criss
# /wiki/The_Following
# /wiki/Al_Pacino
# /wiki/Edmund_Bacon_(architect)
# /wiki/Huffington_Post
# /wiki/Jack_Lemmon
# /wiki/Frost/Nixon_(film)
# /wiki/Russell_Crowe
# /wiki/The_Woodsman_(2004_film)
# /wiki/Apollo_13_(film)
# /wiki/Taking_Chance
# /wiki/Mystic_River_(film)
# /wiki/Kevin_Costner
# /wiki/Jim_Broadbent
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Paul_Newman
# /wiki/Sean_Penn
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/James_Woods
# /wiki/Clint_Eastwood
# /wiki/Ghent_International_Film_Festival
# /wiki/I_Love_Dick_(TV_series)
# /wiki/David_Boreanaz
# /wiki/A_Few_Good_Men_(film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Richard_Chamberlain
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/Phoenix_Film_Festival
# /wiki/Oliver_Stone
# /wiki/Taking_Chance
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Mickey_Rooney
# /wiki/Animal_House
# /wiki/Forest_Whitaker
# /wiki/Internet_meme
# /wiki/HBO_Films
# /wiki/Hollow_Man
# /wiki/Albert_Finney
# /wiki/JFK_(film)
# /wiki/Mystic_River_(film)
# /wiki/Russell_Crowe
# /wiki/Paul_Erd%C5%91s
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Jack_Nicholson
# /wiki/Internet_Broadway_Database
# /wiki/Cosmopolitan_(magazine)
# /wiki/Clint_Eastwood
# /wiki/The_Woodsman_(2004_film)
# /wiki/Bacon_number
# /wiki/Stephen_Moyer
# /wiki/Wild_Things_(film)
# /wiki/Sean_Penn
# /wiki/She%27s_Having_a_Baby
# /wiki/Trivia
# /wiki/Proposition_8
# /wiki/Paul_Erd%C5%91s
# /wiki/Tremors_(film)
# /wiki/Alan_Rickman
# /wiki/Taking_Chance
# /wiki/David_Boreanaz
# /wiki/Losing_Chase
# /wiki/The_Following
# /wiki/Michael_Greif
# /wiki/The_Woodsman_(2004_film)
# /wiki/Philip_Seymour_Hoffman
# /wiki/The_Woodsman_(2004_film)
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/JFK_(film)
# /wiki/Al_Pacino
# /wiki/Raul_Julia
# /wiki/Hollow_Man
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Footloose_(1984_film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Slab_Boys
# /wiki/Phoenix_Film_Festival
# /wiki/Colin_Firth
# /wiki/Flux
# /wiki/Forest_Whitaker
# /wiki/Cosmopolitan_(magazine)
# /wiki/Albert_Finney
# /wiki/The_Following
# /wiki/The_Woodsman_(2004_film)
# /wiki/Idris_Elba
# /wiki/Hollow_Man
# /wiki/Kyle_MacLachlan
# /wiki/Leonardo_DiCaprio
# /wiki/Richard_Dean_Anderson
# /wiki/JFK_(film)
# /wiki/Footloose_(1984_film)
# /wiki/Big_screen
# /wiki/Tracy_Pollan
# /wiki/Mystic_River_(film)
# /wiki/Steve_Guttenberg
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/The_Woodsman_(2004_film)
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Bucknell_University
# /wiki/Erd%C5%91s_number
# /wiki/Dustin_Lance_Black
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Digging_to_China
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Edmund_Bacon_(architect)
# /wiki/Philadelphia
# /wiki/Where_the_Truth_Lies
# /wiki/Beauty_Shop
# /wiki/Phoenix_Theater
# /wiki/Tremors_(film)
# /wiki/Guiding_Light
# /wiki/Flatliners
# /wiki/Cosmopolitan_(magazine)
# /wiki/The_Guardian
# /wiki/Internet_Movie_Database
# /wiki/Bryan_Cranston
# /wiki/Steven_Weber_(actor)
# /wiki/Sean_Penn
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/Flux
# /wiki/Broadcast_Film_Critics_Association
# /wiki/The_Following
# /wiki/Denver_Film_Festival
# /wiki/The_Following
# /wiki/Jim_Broadbent
# /wiki/Bryan_Cranston
# /wiki/Apollo_13_(film)
# /wiki/Matthew_Fox
# /wiki/Geoffrey_Rush
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/James_Dean
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Philadelphia
# /wiki/The_Bacon_Brothers
# /wiki/Jamie_Foxx
# /wiki/The_Following
# /wiki/Steve_Guttenberg
# /wiki/Randy_Quaid
# /wiki/Mads_Mikkelsen
# /wiki/The_Following
# /wiki/Satellite_Awards
# /wiki/The_Following
# /wiki/Jack_Lemmon
# /wiki/Satellite_Awards
# /wiki/James_Garner
# /wiki/SixDegrees.org
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Satellite_Awards
# /wiki/Raul_Julia
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Taking_Chance
# /wiki/HBO_Films
# /wiki/Gary_Sinise
# /wiki/Golden_Globe_Award
# /wiki/Steven_Weber_(actor)
# /wiki/Anthony_Andrews
# /wiki/HBO
# /wiki/The_Following
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/CableACE_Award
# /wiki/Mystic_River_(film)
# /wiki/Will.i.am
# /wiki/Payola
# /wiki/Gary_Oldman
# /wiki/Diner_(film)
# /wiki/The_Following
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/The_Guardian
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Trivia
# /wiki/Sosie_Bacon
# /wiki/Al_Pacino
# /wiki/Jeff_Bridges
# /wiki/Flux
# /wiki/Murder_in_the_First_(film)
# /wiki/Russell_Crowe
# /wiki/Josh_Holloway
# /wiki/Fox_Broadcasting_Company
# /wiki/Al_Pacino
# /wiki/EE_(telecommunications_company)
# /wiki/Gary_Sinise
# /wiki/Fox_Broadcasting_Company
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Forty_Deuce
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Edmund_Bacon_(architect)
# /wiki/Al_Pacino
# /wiki/Black_Mass_(film)
# /wiki/David_Boreanaz
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Tremors_(film)
# /wiki/Hugh_Dancy
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Digging_to_China
# /wiki/Crazy,_Stupid,_Love
# /wiki/Richard_Dean_Anderson
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Hugh_Dancy
# /wiki/Tom_Hiddleston
# /wiki/Academy_Award
# /wiki/Michael_C._Hall
# /wiki/Idris_Elba
# /wiki/Circle_in_the_Square
# /wiki/Mystic_River_(film)
# /wiki/Geoffrey_Rush
# /wiki/Cosmopolitan_(magazine)
# /wiki/Michael_Strobl
# /wiki/Paul_Erd%C5%91s
# /wiki/Edward_James_Olmos
# /wiki/MPAA
# /wiki/Christian_Bale
# /wiki/Finding_Your_Roots
# /wiki/Apollo_13_(film)
# /wiki/Geoffrey_Rush
# /wiki/Daniel_Day-Lewis
# /wiki/Apollo_13_(film)
# /wiki/Bryan_Cranston
# /wiki/Taking_Chance
# /wiki/Ted_Danson
# /wiki/Colin_Firth
# /wiki/Bruce_Campbell
# /wiki/Bryan_Cranston
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Bravo_Otto
# /wiki/James_Garner
# /wiki/Tremors_(film)
# /wiki/Phoenix_Theater
# /wiki/IMDb
# /wiki/Taking_Chance
# /wiki/A_Few_Good_Men_(film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Atom_Egoyan
# /wiki/Black_Mass_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Richard_Chamberlain
# /wiki/Scream_Awards
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/A_Few_Good_Men
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Oscar_Isaac
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Jack_Lemmon
# /wiki/Saturn_Award
# /wiki/Search_for_Tomorrow
# /wiki/United_Kingdom
# /wiki/Kyra_Sedgwick
# /wiki/Stir_of_Echoes
# /wiki/Gary_Sinise
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/Fraternities_and_sororities
# /wiki/Music_album
# /wiki/Bacon_number
# /wiki/Kyle_Chandler
# /wiki/Matthew_Fox
# /wiki/Hugh_Dancy
# /wiki/Edmund_Bacon_(architect)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Oliver_Stone
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Guiding_Light
# /wiki/Michael_Strobl
# /wiki/The_Bacon_Brothers
# /wiki/Internet_Broadway_Database
# /wiki/Big_screen
# /wiki/Huffington_Post
# /wiki/Russell_Crowe
# /wiki/Footloose_(1984_film)
# /wiki/Leonardo_DiCaprio
# /wiki/Screen_Actors_Guild_Award
# /wiki/Wild_Things_(film)
# /wiki/United_Kingdom
# /wiki/The_River_Wild
# /wiki/Jim_Broadbent
# /wiki/JFK_(film)
# /wiki/Joel_Schumacher
# /wiki/Michael_Caine
# /wiki/Taking_Chance
# /wiki/Joel_Schumacher
# /wiki/Wilshire_Ebell_Theatre
# /wiki/Paul_Erd%C5%91s
# /wiki/Where_the_Truth_Lies
# /wiki/David_Koepp
# /wiki/Paul_Erd%C5%91s
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Tremors_(film)
# /wiki/Philadelphia
# /wiki/Sleepers
# /wiki/Taking_Chance
# /wiki/Diner_(film)
# /wiki/Daniel_Stern_(actor)
# /wiki/Bravo_Otto
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Flatliners
# /wiki/Leonardo_DiCaprio
# /wiki/SixDegrees.org
# /wiki/James_Franco
# /wiki/Six_degrees_of_separation
# /wiki/The_New_York_Times
# /wiki/Alan_Rickman
# /wiki/Lemon_Sky
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Where_the_Truth_Lies
# /wiki/Paul_Giamatti
# /wiki/Matthew_Vaughn
# /wiki/Fox_Broadcasting_Company
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Frost/Nixon_(film)
# /wiki/Jack_Nicholson
# /wiki/Jack_Nicholson
# /wiki/The_River_Wild
# /wiki/Robert_Duvall
# /wiki/Pennsylvania
# /wiki/Darren_Criss
# /wiki/She%27s_Having_a_Baby
# /wiki/Wild_Things_(film)
# /wiki/Circle_in_the_Square
# /wiki/Mickey_Rourke
# /wiki/Primetime_Emmy_Award
# /wiki/SixDegrees.org
# /wiki/Michael_Bacon_(musician)
# /wiki/Footloose_(1984_film)
# /wiki/Christian_Bale
# /wiki/Al_Pacino
# /wiki/Darren_Criss
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Egg_as_food
# /wiki/Charles_J._Cooper
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Tim_Robbins
# /wiki/Paul_Erd%C5%91s
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Edmund_Bacon_(architect)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Clint_Eastwood
# /wiki/Taking_Chance
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Golden_Globe_Award
# /wiki/Russell_Crowe
# /wiki/Sosie_Bacon
# /wiki/Internet_meme
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Jeremy_Irons
# /wiki/Slab_Boys
# /wiki/A_Few_Good_Men_(film)
# /wiki/Raul_Julia
# /wiki/Barry_Levinson
# /wiki/Barack_Obama
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/John_Hughes_(filmmaker)
# /wiki/Forest_Whitaker
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Internet_meme
# /wiki/Stanley_Tucci
# /wiki/Wild_Things_(film)
# /wiki/Oliver_Stone
# /wiki/Perry_v._Brown
# /wiki/Robert_Duvall
# /wiki/Footloose_(1984_film)
# /wiki/Russell_Crowe
# /wiki/Losing_Chase
# /wiki/Screen_Actors_Guild_Award
# /wiki/Sosie_Bacon
# /wiki/Michael_Caine
# /wiki/He_Said,_She_Said_(film)
# /wiki/Six_degrees_of_separation
# /wiki/Brian_Dennehy
# /wiki/Henry_Louis_Gates
# /wiki/8_(play)
# /wiki/SixDegrees.org
# /wiki/Teen_Choice_Awards
# /wiki/Huffington_Post
# /wiki/Mads_Mikkelsen
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Big_screen
# /wiki/The_Woodsman_(2004_film)
# /wiki/Kyle_Chandler
# /wiki/Sleepers_(film)
# /wiki/David_Koepp
# /wiki/Pedophile
# /wiki/Paul_Erd%C5%91s
# /wiki/Anthony_Andrews
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Losing_Chase
# /wiki/Oliver_Stone
# /wiki/Edmund_Bacon_(architect)
# /wiki/Russell_Crowe
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Murder_in_the_First_(film)
# /wiki/Bill_Nighy
# /wiki/He_Said,_She_Said_(film)
# /wiki/Hollow_Man
# /wiki/Daniel_Stern_(actor)
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Kevin_Bacon_filmography
# /wiki/Sean_Penn
# /wiki/Rebel_Without_a_Cause
# /wiki/Leonardo_DiCaprio
# /wiki/Lanford_Wilson
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Second_Stage_Theatre
# /wiki/Rebel_Without_a_Cause
# /wiki/Pennsylvania
# /wiki/Matthew_Vaughn
# /wiki/Russell_Crowe
# /wiki/Bravo_Otto
# /wiki/Bucknell_University
# /wiki/Al_Pacino
# /wiki/The_Times
# /wiki/Michael_Bacon_(musician)
# /wiki/Black_Mass_(film)
# /wiki/Murder_in_the_First_(film)
# /wiki/Ben_Kingsley
# /wiki/Perry_v._Brown
# /wiki/Bryan_Cranston
# /wiki/The_River_Wild
# /wiki/Josh_Holloway
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Bernie_Madoff
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Judy_Garland
# /wiki/Flatliners
# /wiki/Robert_Duvall
# /wiki/Internet_Movie_Database
# /wiki/Kyra_Sedgwick
# /wiki/Bill_Nighy
# /wiki/Slab_Boys
# /wiki/Sebastian_Shaw_(comics)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Kyra_Sedgwick
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Crazy,_Stupid,_Love
# /wiki/James_Dean
# /wiki/Academy_Award
# /wiki/Lemon_Sky
# /wiki/CableACE_Award
# /wiki/Colin_Firth
# /wiki/Tremors_(film)
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Kyra_Sedgwick
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Losing_Chase
# /wiki/Mads_Mikkelsen
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/HBO_Films
# /wiki/Holly_Near
# /wiki/He_Said,_She_Said_(film)
# /wiki/Search_for_Tomorrow
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Times
# /wiki/Kevin_Bacon_filmography
# /wiki/Apollo_13_(film)
# /wiki/Bucknell_University
# /wiki/SixDegrees.org
# /wiki/Mickey_Rourke
# /wiki/Scream_Awards
# /wiki/HBO
# /wiki/Primetime_Emmy_Award
# /wiki/Sosie_Bacon
# /wiki/Stir_of_Echoes
# /wiki/David_Boreanaz
# /wiki/Golden_Globe_Award
# /wiki/Sean_Penn
# /wiki/Ghent_International_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Sean_Penn
# /wiki/The_Following
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Alan_Rickman
# /wiki/Kyle_MacLachlan
# /wiki/Phoenix_Film_Festival
# /wiki/Daniel_Stern_(actor)
# /wiki/Kevin_Bacon_filmography
# /wiki/Golden_Globe_Award
# /wiki/The_Bacon_Brothers
# /wiki/Flux
# /wiki/Jack_Lemmon
# /wiki/The_Woodsman_(2004_film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Ted_Danson
# /wiki/TV_Guide_Award
# /wiki/Internet_Broadway_Database
# /wiki/The_Big_Picture_(1989_film)
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Sosie_Bacon
# /wiki/Forest_Whitaker
# /wiki/Perry_v._Brown
# /wiki/Joaquin_Phoenix
# /wiki/Dustin_Hoffman
# /wiki/Internet_Broadway_Database
# /wiki/Apollo_13_(film)
# /wiki/Michael_Keaton
# /wiki/James_Dean
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/Stir_of_Echoes
# /wiki/Losing_Chase
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Bacon_(musician)
# /wiki/Six_degrees_of_separation
# /wiki/Kevin_Bacon_filmography
# /wiki/SixDegrees.org
# /wiki/The_Following
# /wiki/Access_Hollywood
# /wiki/Crazy,_Stupid,_Love
# /wiki/Tracy_Pollan
# /wiki/Charles_J._Cooper
# /wiki/Frost/Nixon_(film)
# /wiki/Russell_Crowe
# /wiki/Albert_Finney
# /wiki/A_Few_Good_Men_(film)
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Woodsman_(2004_film)
# /wiki/Wild_Things_(film)
# /wiki/Julia_R._Masterman_High_School
# /wiki/HBO
# /wiki/Fox_Broadcasting_Company
# /wiki/Losing_Chase
# /wiki/SixDegrees.org
# /wiki/Steve_Guttenberg
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Sleepers_(film)
# /wiki/Giffoni_Film_Festival
# /wiki/Sosie_Bacon
# /wiki/Denver_Film_Festival
# /wiki/Academy_Award
# /wiki/Ben_Browder
# /wiki/Joel_Schumacher
# /wiki/Jack_Nicholson
# /wiki/Teen_Choice_Awards
# /wiki/The_River_Wild
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/William_H._Macy
# /wiki/Bacon_number
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Sleepers
# /wiki/The_River_Wild
# /wiki/Ian_McKellen
# /wiki/Darren_Criss
# /wiki/Colin_Firth
# /wiki/Music_album
# /wiki/Footloose_(1984_film)
# /wiki/Paul_Giamatti
# /wiki/Patriots_Day_(film)
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Patriots_Day_(film)
# /wiki/The_Following
# /wiki/Perry_v._Brown
# /wiki/Hollywood_Walk_of_Fame
# /wiki/John_Hughes_(filmmaker)
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Matthew_Vaughn
# /wiki/Robert_Patrick
# /wiki/Beau_Bridges
# /wiki/Erd%C5%91s_number
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Mickey_Rooney
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Andrew_Lincoln
# /wiki/Paul_Newman
# /wiki/Murder_in_the_First_(film)
# /wiki/Wilshire_Ebell_Theatre
# /wiki/Mystic_River_(film)
# /wiki/Casey_Affleck
# /wiki/Sean_Penn
# /wiki/The_Following
# /wiki/Russell_Crowe
# /wiki/Apollo_13_(film)
# /wiki/Paul_Giamatti
# /wiki/Guiding_Light
# /wiki/Phoenix_Film_Festival
# /wiki/Charles_J._Cooper
# /wiki/David_Boreanaz
# /wiki/Primetime_Emmy_Award
# /wiki/Flatliners
# /wiki/Paul_Erd%C5%91s
# /wiki/A_Few_Good_Men
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/The_Following
# /wiki/Erd%C5%91s_number
# /wiki/Golden_Globe_Award
# /wiki/Bacon_number
# /wiki/Phoenix_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Beauty_Shop
# /wiki/Music_album
# /wiki/Jeremy_Irons
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/James_Garner
# /wiki/Wild_Things_(film)
# /wiki/Screen_Actors_Guild_Award
# /wiki/Six_degrees_of_separation
# /wiki/Six_degrees_of_separation
# /wiki/Bill_Nighy
# /wiki/Jeremy_Irons
# /wiki/The_Following
# /wiki/Russell_Crowe
# /wiki/Andrew_Lincoln
# /wiki/Barack_Obama
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/Black_Mass_(film)
# /wiki/The_Following
# /wiki/The_Woodsman_(2004_film)
# /wiki/James_Garner
# /wiki/Taking_Chance
# /wiki/Losing_Chase
# /wiki/Julia_R._Masterman_High_School
# /wiki/Ted_Danson
# /wiki/Christopher_Reeve
# /wiki/Forest_Whitaker
# /wiki/The_Bacon_Brothers
# /wiki/Daniel_Stern_(actor)
# /wiki/Where_the_Truth_Lies
# /wiki/Sean_Penn
# /wiki/Randy_Quaid
# /wiki/Jim_Broadbent
# /wiki/Al_Pacino
# /wiki/SixDegrees.org
# /wiki/Chlotrudis_Awards
# /wiki/Steve_Guttenberg
# /wiki/Jack_Nicholson
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Following
# /wiki/Taking_Chance
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Atom_Egoyan
# /wiki/Idris_Elba
# /wiki/Desert_Storm
# /wiki/Taking_Chance
# /wiki/Randy_Quaid
# /wiki/Matthew_Fox
# /wiki/Robert_Patrick
# /wiki/Taking_Chance
# /wiki/Daniel_Stern_(actor)
# /wiki/Patriots_Day_(film)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Murder_in_the_First_(film)
# /wiki/Barry_Levinson
# /wiki/Sleepers_(film)
# /wiki/TV_Guide_Award
# /wiki/Sean_Penn
# /wiki/Internet_Broadway_Database
# /wiki/Michael_Greif
# /wiki/Sean_Penn
# /wiki/Russell_Crowe
# /wiki/Digging_to_China
# /wiki/The_Bacon_Brothers
# /wiki/Stacy_Keach
# /wiki/Beau_Bridges
# /wiki/Apollo_13_(film)
# /wiki/Sleepers
# /wiki/Ben_Browder
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Al_Pacino
# /wiki/She%27s_Having_a_Baby
# /wiki/Ewan_McGregor
# /wiki/Wilshire_Ebell_Theatre
# /wiki/Elizabeth_Perkins
# /wiki/James_Woods
# /wiki/Music_album
# /wiki/Matthew_Fox
# /wiki/Guiding_Light
# /wiki/Finding_Your_Roots
# /wiki/Randy_Quaid
# /wiki/Barry_Levinson
# /wiki/Robert_Patrick
# /wiki/Erd%C5%91s_number
# /wiki/Russell_Crowe
# /wiki/Casey_Affleck
# /wiki/Sean_Penn
# /wiki/Joaquin_Phoenix
# /wiki/Mystic_River_(film)
# /wiki/Stephen_Moyer
# /wiki/Social_networks
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Daniel_Day-Lewis
# /wiki/Gary_Sinise
# /wiki/Tremors_(film)
# /wiki/Philadelphia
# /wiki/Black_Mass_(film)
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Philadelphia
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Mickey_Rooney
# /wiki/Apollo_13_(film)
# /wiki/The_Austin_Chronicle
# /wiki/Raul_Julia
# /wiki/Ted_Danson
# /wiki/Christopher_Reeve
# /wiki/Bryan_Cranston
# /wiki/The_Following
# /wiki/Sean_Penn
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Screen_Actors_Guild_Award
# /wiki/The_Woodsman_(2004_film)
# /wiki/Edmund_Bacon_(architect)
# /wiki/Matthew_Fox
# /wiki/Six_degrees_of_separation
# /wiki/Darren_Criss
# /wiki/Joaquin_Phoenix
# /wiki/Wild_Things_(film)
# /wiki/Tim_Robbins
# /wiki/Al_Pacino
# /wiki/A_Few_Good_Men_(film)
# /wiki/Internet_meme
# /wiki/Meryl_Streep
# /wiki/Michael_Caine
# /wiki/Losing_Chase
# /wiki/Clint_Eastwood
# /wiki/Pennsylvania
# /wiki/Sam_Rockwell
# /wiki/SixDegrees.org
# /wiki/Black_Mass_(film)
# /wiki/Flatliners
# /wiki/Chlotrudis_Awards
# /wiki/Michael_Strobl
# /wiki/Hugh_Dancy
# /wiki/Kyle_Chandler
# /wiki/TV_Guide_Award
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Russell_Crowe
# /wiki/The_River_Wild
# /wiki/Losing_Chase
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Manhattan
# /wiki/Guiding_Light
# /wiki/Mystic_River_(film)
# /wiki/Stacy_Keach
# /wiki/Hugh_Dancy
# /wiki/The_Following
# /wiki/Michael_Douglas
# /wiki/Ewan_McGregor
# /wiki/Search_for_Tomorrow
# /wiki/Colin_Firth
# /wiki/Second_Stage_Theatre
# /wiki/Jamie_Foxx
# /wiki/Tremors_(film)
# /wiki/The_River_Wild
# /wiki/Stephen_Moyer
# /wiki/Sleepers
# /wiki/Rebel_Without_a_Cause
# /wiki/Anthony_Andrews
# /wiki/Charles_J._Cooper
# /wiki/Apollo_13_(film)
# /wiki/The_Following
# /wiki/Russell_Crowe
# /wiki/Taking_Chance
# /wiki/Randy_Quaid
# /wiki/Joel_Schumacher
# /wiki/Kyra_Sedgwick
# /wiki/Second_Stage_Theatre
# /wiki/A_Few_Good_Men_(film)
# /wiki/Phoenix_Theater
# /wiki/Kyra_Sedgwick
# /wiki/Ghent_International_Film_Festival
# /wiki/Joel_Schumacher
# /wiki/SixDegrees.org
# /wiki/Paul_Verhoeven
# /wiki/Paul_Giamatti
# /wiki/Henry_Louis_Gates
# /wiki/Sean_Penn
# /wiki/Hollow_Man
# /wiki/TV_Guide_Award
# /wiki/Ellen_Barkin
# /wiki/Manhattan
# /wiki/Edward_James_Olmos
# /wiki/Jack_Lemmon
# /wiki/Mystic_River_(film)
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Primetime_Emmy_Award
# /wiki/Flatliners
# /wiki/Kevin_Kline
# /wiki/Loverboy_(2005_film)
# /wiki/Al_Pacino
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Jack_Lemmon
# /wiki/Al_Pacino
# /wiki/Pyrates
# /wiki/Seattle_International_Film_Festival
# /wiki/Slab_Boys
# /wiki/Gary_Oldman
# /wiki/George_Clooney
# /wiki/Jack_Nicholson
# /wiki/The_Following
# /wiki/Oliver_Stone
# /wiki/Phoenix_Theater
# /wiki/Internet_meme
# /wiki/Ghent_International_Film_Festival
# /wiki/Joel_Schumacher
# /wiki/Screen_Actors_Guild_Award
# /wiki/Edmund_Bacon_(architect)
# /wiki/Taking_Chance
# /wiki/Nancy_Mills
# /wiki/Beau_Bridges
# /wiki/Kevin_Bacon_filmography
# /wiki/JFK_(film)
# /wiki/Sean_Penn
# /wiki/Primetime_Emmy_Award
# /wiki/Lanford_Wilson
# /wiki/She%27s_Having_a_Baby
# /wiki/Where_the_Truth_Lies
# /wiki/Phoenix_Theater
# /wiki/Tom_Hiddleston
# /wiki/David_Boreanaz
# /wiki/Kyra_Sedgwick
# /wiki/Dustin_Hoffman
# /wiki/Alan_Rickman
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Al_Pacino
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/Bravo_Otto
# /wiki/Leonardo_DiCaprio
# /wiki/Apollo_13_(film)
# /wiki/Phoenix_Film_Festival
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Taking_Chance
# /wiki/Taking_Chance
# /wiki/Ponzi_scheme
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/Beau_Bridges
# /wiki/The_Following
# /wiki/Paul_Verhoeven
# /wiki/Giffoni_Film_Festival
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Paul_Erd%C5%91s
# /wiki/Apollo_13_(film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Dustin_Hoffman
# /wiki/Scream_Awards
# /wiki/Mark_Ruffalo
# /wiki/Apollo_13_(film)
# /wiki/Paul_Erd%C5%91s
# /wiki/Jim_Broadbent
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Darren_Criss
# /wiki/Seattle_International_Film_Festival
# /wiki/Second_Stage_Theatre
# /wiki/Richard_Dean_Anderson
# /wiki/Oliver_Stone
# /wiki/Andrew_Lincoln
# /wiki/IMDb
# /wiki/The_Woodsman_(2004_film)
# /wiki/James_Franco
# /wiki/James_Garner
# /wiki/Beauty_Shop
# /wiki/Scream_Awards
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Phoenix_Film_Festival
# /wiki/Obie_Award
# /wiki/Russell_Crowe
# /wiki/Paul_Verhoeven
# /wiki/Slab_Boys
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Taking_Chance
# /wiki/Cosmopolitan_(magazine)
# /wiki/Hollow_Man
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Loverboy_(2005_film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Six_degrees_of_separation
# /wiki/Anthony_Andrews
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/HBO
# /wiki/Michael_Caine
# /wiki/The_Bacon_Brothers
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/Billy_Bob_Thornton
# /wiki/The_Following
# /wiki/James_Garner
# /wiki/Gary_Oldman
# /wiki/Hollow_Man
# /wiki/Erd%C5%91s_number
# /wiki/Michael_Greif
# /wiki/The_Following
# /wiki/Murder_in_the_First_(film)
# /wiki/Golden_Globe_Award
# /wiki/Access_Hollywood
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Hollow_Man
# /wiki/Russell_Crowe
# /wiki/Steven_Weber_(actor)
# /wiki/Hugh_Dancy
# /wiki/The_River_Wild
# /wiki/Mickey_Rourke
# /wiki/Sosie_Bacon
# /wiki/Crazy,_Stupid,_Love
# /wiki/Apollo_13_(film)
# /wiki/Loverboy_(2005_film)
# /wiki/CableACE_Award
# /wiki/Robert_Patrick
# /wiki/Mystic_River_(film)
# /wiki/The_Following
# /wiki/Mystic_River_(film)
# /wiki/Hollow_Man
# /wiki/Mark_Ruffalo
# /wiki/Loverboy_(2005_film)
# /wiki/Wild_Things_(film)
# /wiki/Darren_Criss
# /wiki/Digging_to_China
# /wiki/Gary_Sinise
# /wiki/Diner_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Christian_Bale
# /wiki/Robert_Patrick
# /wiki/Satellite_Awards
# /wiki/Anthony_Andrews
# /wiki/Forest_Whitaker
# /wiki/Tim_Daly
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Dustin_Lance_Black
# /wiki/Flatliners
# /wiki/Desert_Storm
# /wiki/Leonardo_DiCaprio
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Internet_Broadway_Database
# /wiki/Josh_Holloway
# /wiki/Internet_meme
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Wilshire_Ebell_Theatre
# /wiki/Kyle_Chandler
# /wiki/Big_screen
# /wiki/Josh_Holloway
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Russell_Crowe
# /wiki/Bruce_Campbell
# /wiki/Independent_Spirit_Awards
# /wiki/Academy_Award
# /wiki/The_Following
# /wiki/Paul_Giamatti
# /wiki/Flatliners
# /wiki/Darren_Criss
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Lanford_Wilson
# /wiki/Michael_Greif
# /wiki/Giffoni_Film_Festival
# /wiki/MPAA
# /wiki/Idris_Elba
# /wiki/Bravo_Otto
# /wiki/Robert_Duvall
# /wiki/Michael_Bacon_(musician)
# /wiki/Idris_Elba
# /wiki/Russell_Crowe
# /wiki/Barack_Obama
# /wiki/Sean_Penn
# /wiki/Frost/Nixon_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Woodsman_(2004_film)
# /wiki/Golden_Globe_Award
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Academy_Award
# /wiki/TV_Guide_Award
# /wiki/James_Woods
# /wiki/Geoffrey_Rush
# /wiki/Stanley_Tucci
# /wiki/Tim_Daly
# /wiki/Dustin_Hoffman
# /wiki/Lanford_Wilson
# /wiki/Footloose_(1984_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Internet_Movie_Database
# /wiki/Ben_Kingsley
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/Seattle_International_Film_Festival
# /wiki/Russell_Crowe
# /wiki/Geoffrey_Rush
# /wiki/Crazy,_Stupid,_Love
# /wiki/Wild_Things_(film)
# /wiki/Mickey_Rooney
# /wiki/Rebel_Without_a_Cause
# /wiki/Billy_Bob_Thornton
# /wiki/Cosmopolitan_(magazine)
# /wiki/Cosmopolitan_(magazine)
# /wiki/Ving_Rhames
# /wiki/Apollo_13_(film)
# /wiki/Bucknell_University
# /wiki/Big_screen
# /wiki/Loverboy_(2005_film)
# /wiki/Sleepers_(film)
# /wiki/Matthew_Fox
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Diner_(film)
# /wiki/Mystic_River_(film)
# /wiki/Paul_Erd%C5%91s
# /wiki/Ben_Kingsley
# /wiki/Screen_Actors_Guild_Award
# /wiki/Ted_Danson
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/Holly_Near
# /wiki/Mystic_River_(film)
# /wiki/James_Dean
# /wiki/Barry_Levinson
# /wiki/Apollo_13_(film)
# /wiki/Apollo_13_(film)
# /wiki/Giffoni_Film_Festival
# /wiki/Al_Pacino
# /wiki/Elizabeth_Perkins
# /wiki/Wild_Things_(film)
# /wiki/Geoffrey_Rush
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/The_Bacon_Brothers
# /wiki/Darren_Criss
# /wiki/Teen_Choice_Awards
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Alan_Rickman
# /wiki/James_Dean
# /wiki/Brian_Dennehy
# /wiki/Jeff_Bridges
# /wiki/Ghent_International_Film_Festival
# /wiki/TV_Guide_Award
# /wiki/Paul_Newman
# /wiki/Andrew_Lincoln
# /wiki/Geoffrey_Rush
# /wiki/Denver_Film_Festival
# /wiki/Chlotrudis_Awards
# /wiki/Jamie_Foxx
# /wiki/Ghent_International_Film_Festival
# /wiki/Dustin_Lance_Black
# /wiki/Robert_Patrick
# /wiki/James_Woods
# /wiki/Barry_Levinson
# /wiki/Giffoni_Film_Festival
# /wiki/Bacon_number
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Paul_Newman
# /wiki/Stanley_Tucci
# /wiki/Primetime_Emmy_Award
# /wiki/Mark_Ruffalo
# /wiki/Glory_Van_Scott
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Following
# /wiki/He_Said,_She_Said_(film)
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Rachel_Blanchard
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Clint_Eastwood
# /wiki/Murder_in_the_First_(film)
# /wiki/Philadelphia
# /wiki/Ellen_Barkin
# /wiki/Jack_Lemmon
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Loverboy_(2005_film)
# /wiki/Steven_Weber_(actor)
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Henry_Louis_Gates
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Murder_in_the_First_(film)
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Erd%C5%91s_number
# /wiki/Russell_Crowe
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Taking_Chance
# /wiki/Erd%C5%91s_number
# /wiki/Blockbuster_(entertainment)
# /wiki/Geoffrey_Rush
# /wiki/Matthew_Fox
# /wiki/The_Guardian
# /wiki/Randy_Quaid
# /wiki/Gary_Sinise
# /wiki/Lortel_Archives
# /wiki/Wild_Things_(film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Gary_Sinise
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Elizabeth_Perkins
# /wiki/Raul_Julia
# /wiki/Stir_of_Echoes
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Satellite_Awards
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Hollow_Man
# /wiki/Glory_Van_Scott
# /wiki/Robert_Duvall
# /wiki/Taking_Chance
# /wiki/Broadcast_Film_Critics_Association
# /wiki/EE_(telecommunications_company)
# /wiki/Glory_Van_Scott
# /wiki/Bryan_Cranston
# /wiki/Glory_Van_Scott
# /wiki/Six_degrees_of_separation
# /wiki/Michael_Douglas
# /wiki/SixDegrees.org
# /wiki/Jack_Lemmon
# /wiki/Elizabeth_Perkins
# /wiki/The_Following
# /wiki/Crazy,_Stupid,_Love
# /wiki/The_River_Wild
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Sosie_Bacon
# /wiki/Loverboy_(2005_film)
# /wiki/Mystic_River_(film)
# /wiki/Oscar_Isaac
# /wiki/MPAA
# /wiki/Boston_Society_of_Film_Critics
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Giffoni_Film_Festival
# /wiki/Tim_Daly
# /wiki/Slab_Boys
# /wiki/Michael_Keaton
# /wiki/Stacy_Keach
# /wiki/Gary_Oldman
# /wiki/Sleepers_(film)
# /wiki/Bryan_Cranston
# /wiki/Oliver_Stone
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Social_networks
# /wiki/Sean_Penn
# /wiki/EE_(telecommunications_company)
# /wiki/James_Garner
# /wiki/Dustin_Hoffman
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/Nancy_Mills
# /wiki/Paul_Erd%C5%91s
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Guardian
# /wiki/The_Bacon_Brothers
# /wiki/Holly_Near
# /wiki/Richard_Chamberlain
# /wiki/David_Boreanaz
# /wiki/Bruce_Campbell
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Trivia
# /wiki/Apollo_13_(film)
# /wiki/Loverboy_(2005_film)
# /wiki/Stir_of_Echoes
# /wiki/A_Few_Good_Men_(film)
# /wiki/Anthony_Andrews
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Daniel_Stern_(actor)
# /wiki/The_Austin_Chronicle
# /wiki/The_Woodsman_(2004_film)
# /wiki/Perry_v._Brown
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Internet_meme
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/Geoffrey_Rush
# /wiki/Ben_Browder
# /wiki/Alan_Rickman
# /wiki/Trivia
# /wiki/Scream_Awards
# /wiki/Independent_Spirit_Awards
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Hugh_Dancy
# /wiki/Robert_Duvall
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Forty_Deuce
# /wiki/Egg_as_food
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Mark_Ruffalo
# /wiki/Sam_Heughan
# /wiki/Flatliners
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Guardian
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Stir_of_Echoes
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Beau_Bridges
# /wiki/Ellen_Barkin
# /wiki/AllMovie
# /wiki/Al_Pacino
# /wiki/Stacy_Keach
# /wiki/Music_album
# /wiki/The_Bacon_Brothers
# /wiki/Slab_Boys
# /wiki/Charles_J._Cooper
# /wiki/Mystic_River_(film)
# /wiki/Colin_Firth
# /wiki/Russell_Crowe
# /wiki/SixDegrees.org
# /wiki/The_Guardian
# /wiki/Forest_Whitaker
# /wiki/Animal_House
# /wiki/Glory_Van_Scott
# /wiki/Elizabeth_Perkins
# /wiki/Guiding_Light
# /wiki/Diner_(film)
# /wiki/A_Few_Good_Men
# /wiki/Jack_Nicholson
# /wiki/Erd%C5%91s_number
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Andrew_Lincoln
# /wiki/Albert_Finney
# /wiki/Leonardo_DiCaprio
# /wiki/Music_album
# /wiki/James_Garner
# /wiki/Denver_Film_Festival
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Fox_Broadcasting_Company
# /wiki/Ponzi_scheme
# /wiki/HBO
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Philip_Seymour_Hoffman
# /wiki/James_Franco
# /wiki/Edmund_Bacon_(architect)
# /wiki/Leonardo_DiCaprio
# /wiki/Lemon_Sky
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Sebastian_Shaw_(comics)
# /wiki/CableACE_Award
# /wiki/David_Boreanaz
# /wiki/Giffoni_Film_Festival
# /wiki/Raul_Julia
# /wiki/Jack_Lemmon
# /wiki/Sosie_Bacon
# /wiki/Rachel_Blanchard
# /wiki/Anthony_Andrews
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Obie_Award
# /wiki/Animal_House
# /wiki/Sean_Penn
# /wiki/Clint_Eastwood
# /wiki/CableACE_Award
# /wiki/Darren_Criss
# /wiki/Tremors_(film)
# /wiki/Pennsylvania
# /wiki/Animal_House
# /wiki/Taking_Chance
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Loverboy_(2005_film)
# /wiki/Tremors_(film)
# /wiki/Teen_Choice_Awards
# /wiki/Saturn_Award
# /wiki/Michael_Douglas
# /wiki/Michael_C._Hall
# /wiki/Taking_Chance
# /wiki/Kyle_MacLachlan
# /wiki/Gary_Oldman
# /wiki/The_River_Wild
# /wiki/Russell_Crowe
# /wiki/IMDb
# /wiki/Murder_in_the_First_(film)
# /wiki/Michael_C._Hall
# /wiki/Scream_Awards
# /wiki/Bryan_Cranston
# /wiki/Oscar_Isaac
# /wiki/The_Woodsman_(2004_film)
# /wiki/MPAA
# /wiki/Joel_Schumacher
# /wiki/Kevin_Bacon_filmography
# /wiki/Sosie_Bacon
# /wiki/I_Love_Dick_(TV_series)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Guiding_Light
# /wiki/Phoenix_Theater
# /wiki/The_Guardian
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Losing_Chase
# /wiki/MPAA_film_rating_system
# /wiki/Russell_Crowe
# /wiki/Chlotrudis_Awards
# /wiki/Music_album
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Val_Kilmer
# /wiki/Bill_Nighy
# /wiki/Joaquin_Phoenix
# /wiki/Satellite_Awards
# /wiki/Tim_Daly
# /wiki/Footloose_(1984_film)
# /wiki/Screen_Actors_Guild_Award
# /wiki/SixDegrees.org
# /wiki/Losing_Chase
# /wiki/SixDegrees.org
# /wiki/Manhattan
# /wiki/Brian_Dennehy
# /wiki/Richard_Dean_Anderson
# /wiki/Hollow_Man
# /wiki/Where_the_Truth_Lies
# /wiki/The_Following
# /wiki/Lanford_Wilson
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/Crazy,_Stupid,_Love
# /wiki/Saturn_Award
# /wiki/Digging_to_China
# /wiki/Barack_Obama
# /wiki/Chlotrudis_Awards
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/The_River_Wild
# /wiki/Screen_Actors_Guild_Award
# /wiki/Michael_Caine
# /wiki/Payola
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyra_Sedgwick
# /wiki/David_Boreanaz
# /wiki/Murder_in_the_First_(film)
# /wiki/Sosie_Bacon
# /wiki/Philip_Seymour_Hoffman
# /wiki/Kevin_Costner
# /wiki/Ghent_International_Film_Festival
# /wiki/Jack_Nicholson
# /wiki/Ghent_International_Film_Festival
# /wiki/Golden_Globe_Award
# /wiki/The_Woodsman_(2004_film)
# ...
# /wiki/Al_Pacino
# /wiki/Andrew_Lincoln
# /wiki/Golden_Globe_Award
# /wiki/Bacon_number
# /wiki/Diner_(film)
# /wiki/Circle_in_the_Square
# /wiki/Hollow_Man
# /wiki/Glory_Van_Scott
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Slab_Boys
# /wiki/Robert_Patrick
# /wiki/Ponzi_scheme
# /wiki/David_Boreanaz
# /wiki/Slab_Boys
# /wiki/Bravo_Otto
# /wiki/Tim_Robbins
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Circle_in_the_Square
# /wiki/The_Following
# /wiki/The_Following
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Jack_Nicholson
# /wiki/Randy_Quaid
# /wiki/Perry_v._Brown
# /wiki/Ben_Browder
# /wiki/Lanford_Wilson
# /wiki/Bravo_Otto
# /wiki/Oscar_Isaac
# /wiki/Stir_of_Echoes
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Primetime_Emmy_Award
# /wiki/Bryan_Cranston
# /wiki/The_River_Wild
# /wiki/Barry_Levinson
# /wiki/Apollo_13_(film)
# /wiki/Access_Hollywood
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Daniel_Day-Lewis
# /wiki/Ted_Danson
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Golden_Globe_Award
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Paul_Erd%C5%91s
# /wiki/Darren_Criss
# /wiki/Hollow_Man
# /wiki/Holly_Near
# /wiki/Tremors_(film)
# /wiki/Clint_Eastwood
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Robert_Patrick
# /wiki/Screen_Actors_Guild_Award
# /wiki/Daniel_Day-Lewis
# /wiki/Randy_Quaid
# /wiki/Paul_Erd%C5%91s
# /wiki/Huffington_Post
# /wiki/Stir_of_Echoes
# /wiki/Loverboy_(2005_film)
# /wiki/Taking_Chance
# /wiki/MPAA_film_rating_system
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Blockbuster_(entertainment)
# /wiki/Sean_Penn
# /wiki/James_Woods
# /wiki/Jack_Nicholson
# /wiki/JFK_(film)
# /wiki/Kevin_Bacon_filmography
# /wiki/Robert_Duvall
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Matthew_Vaughn
# /wiki/Michael_Douglas
# /wiki/E!_People%27s_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Second_Stage_Theatre
# /wiki/Footloose_(1984_film)
# /wiki/Murder_in_the_First_(film)
# /wiki/Randy_Quaid
# /wiki/Music_album
# /wiki/Bryan_Cranston
# /wiki/The_Times
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Sleepers
# /wiki/Sam_Rockwell
# /wiki/Murder_in_the_First_(film)
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Ellen_Barkin
# /wiki/Kyle_MacLachlan
# /wiki/Robert_Duvall
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Daniel_Stern_(actor)
# /wiki/Six_degrees_of_separation
# /wiki/David_Boreanaz
# /wiki/Kyra_Sedgwick
# /wiki/Christian_Bale
# /wiki/Brian_Dennehy
# /wiki/Pennsylvania
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/James_Dean
# /wiki/United_Kingdom
# /wiki/Michael_Caine
# /wiki/Gary_Sinise
# /wiki/Loverboy_(2005_film)
# /wiki/David_Boreanaz
# /wiki/Philip_Seymour_Hoffman
# /wiki/Murder_in_the_First_(film)
# /wiki/Academy_Award
# /wiki/Raul_Julia
# /wiki/Finding_Your_Roots
# /wiki/Friday_the_13th_(1980_film)
# /wiki/The_River_Wild
# /wiki/Pyrates
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Kyra_Sedgwick
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Philadelphia
# /wiki/Jamie_Foxx
# /wiki/A_Few_Good_Men_(film)
# /wiki/Bruce_Campbell
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Alan_Rickman
# /wiki/Kyra_Sedgwick
# /wiki/William_H._Macy
# /wiki/Rebel_Without_a_Cause
# /wiki/PBS
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/Al_Pacino
# /wiki/Raul_Julia
# /wiki/Russell_Crowe
# /wiki/Holly_Near
# /wiki/Pyrates
# /wiki/David_Boreanaz
# /wiki/Seattle_International_Film_Festival
# /wiki/Academy_Award
# /wiki/Wild_Things_(film)
# /wiki/TV_Guide_Award
# /wiki/Atom_Egoyan
# /wiki/Matthew_Fox
# /wiki/Access_Hollywood
# /wiki/Colin_Firth
# /wiki/Mystic_River_(film)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Diner_(film)
# /wiki/Loverboy_(2005_film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Steve_Guttenberg
# /wiki/Bryan_Cranston
# /wiki/Tracy_Pollan
# /wiki/Al_Pacino
# /wiki/Mystic_River_(film)
# /wiki/Mads_Mikkelsen
# /wiki/CableACE_Award
# /wiki/Anthony_Andrews
# /wiki/James_Dean
# /wiki/A_Few_Good_Men
# /wiki/The_Following
# /wiki/I_Love_Dick_(TV_series)
# /wiki/The_Following
# /wiki/Search_for_Tomorrow
# /wiki/Wild_Things_(film)
# /wiki/Mark_Ruffalo
# /wiki/EE_(telecommunications_company)
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Rebel_Without_a_Cause
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Academy_Award
# /wiki/Kyra_Sedgwick
# /wiki/Dustin_Hoffman
# /wiki/Henry_Louis_Gates
# /wiki/Hollow_Man
# /wiki/Al_Pacino
# /wiki/Leonardo_DiCaprio
# /wiki/The_Austin_Chronicle
# /wiki/Gary_Sinise
# /wiki/Loverboy_(2005_film)
# /wiki/Brian_Dennehy
# /wiki/SixDegrees.org
# /wiki/Mystic_River_(film)
# /wiki/Russell_Crowe
# /wiki/8_(play)
# /wiki/Gary_Sinise
# /wiki/Gary_Sinise
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Mystic_River_(film)
# /wiki/Bill_Nighy
# /wiki/Meryl_Streep
# /wiki/Mystic_River_(film)
# /wiki/Jack_Nicholson
# /wiki/Bill_Nighy
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/The_Following
# /wiki/A_Few_Good_Men_(film)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Paul_Newman
# /wiki/Taking_Chance
# /wiki/Paul_Giamatti
# /wiki/Bucknell_University
# /wiki/The_Woodsman_(2004_film)
# /wiki/Henry_Louis_Gates
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/David_Boreanaz
# /wiki/Sam_Heughan
# /wiki/A_Few_Good_Men_(film)
# /wiki/MPAA_film_rating_system
# /wiki/Al_Pacino
# /wiki/Paul_Newman
# /wiki/Gary_Sinise
# /wiki/Sleepers
# /wiki/Tom_Hiddleston
# /wiki/Academy_Award
# /wiki/Taking_Chance
# /wiki/Forty_Deuce
# /wiki/Crazy,_Stupid,_Love
# /wiki/Access_Hollywood
# /wiki/Murder_in_the_First_(film)
# /wiki/Bucknell_University
# /wiki/Jeremy_Irons
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Jamie_Foxx
# /wiki/Daniel_Day-Lewis
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/Golden_Globe_Award
# /wiki/Jack_Lemmon
# /wiki/Tremors_(film)
# /wiki/Lemon_Sky
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Stanley_Tucci
# /wiki/Search_for_Tomorrow
# /wiki/Sosie_Bacon
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Mystic_River_(film)
# /wiki/Saturn_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Colin_Firth
# /wiki/The_Guardian
# /wiki/Philadelphia
# /wiki/David_Boreanaz
# /wiki/Robert_Duvall
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/The_Following
# /wiki/Daniel_Day-Lewis
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Darren_Criss
# /wiki/The_Woodsman_(2004_film)
# /wiki/Erd%C5%91s_number
# /wiki/Bravo_Otto
# /wiki/Jack_Lemmon
# /wiki/Bacon_number
# /wiki/Guiding_Light
# /wiki/Diner_(film)
# /wiki/8_(play)
# /wiki/Robert_Duvall
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Christian_Bale
# /wiki/PBS
# /wiki/Footloose_(1984_film)
# /wiki/Obie_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Michael_Greif
# /wiki/Kevin_Costner
# /wiki/Hollywood_Walk_of_Fame
# /wiki/HBO
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Gary_Sinise
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Huffington_Post
# /wiki/Forty_Deuce
# /wiki/The_Following
# /wiki/Erd%C5%91s_number
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Jeremy_Irons
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Michael_Bacon_(musician)
# /wiki/Fraternities_and_sororities
# /wiki/Internet_meme
# /wiki/Footloose_(1984_film)
# /wiki/Ponzi_scheme
# /wiki/Animal_House
# /wiki/Paul_Erd%C5%91s
# /wiki/Frost/Nixon_(film)
# /wiki/Academy_Award
# /wiki/Independent_Spirit_Awards
# /wiki/Bravo_Otto
# /wiki/EE_(telecommunications_company)
# /wiki/James_Woods
# /wiki/Mystic_River_(film)
# /wiki/Mystic_River_(film)
# /wiki/Internet_Movie_Database
# /wiki/Academy_Award
# /wiki/The_Following
# /wiki/Josh_Holloway
# /wiki/Losing_Chase
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/The_Guardian
# /wiki/Pennsylvania
# /wiki/Perry_v._Brown
# /wiki/Anthony_Andrews
# /wiki/Jeremy_Irons
# /wiki/Saturn_Award
# /wiki/Hollow_Man
# /wiki/Kevin_Kline
# /wiki/Oliver_Stone
# /wiki/Beauty_Shop
# /wiki/HBO
# /wiki/Animal_House
# /wiki/Golden_Globe_Award
# /wiki/Lanford_Wilson
# /wiki/David_Boreanaz
# /wiki/Kevin_Bacon_filmography
# /wiki/Slab_Boys
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Steve_Guttenberg
# /wiki/Al_Pacino
# /wiki/Ghent_International_Film_Festival
# /wiki/Oscar_Isaac
# /wiki/Glory_Van_Scott
# /wiki/Perry_v._Brown
# /wiki/Taking_Chance
# /wiki/Brian_Dennehy
# /wiki/Tim_Daly
# /wiki/Gary_Sinise
# /wiki/Access_Hollywood
# /wiki/Nancy_Mills
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Kevin_Costner
# /wiki/Ben_Kingsley
# /wiki/Loverboy_(2005_film)
# /wiki/Jamie_Foxx
# /wiki/Flux
# /wiki/SixDegrees.org
# /wiki/Sean_Penn
# /wiki/Jack_Lemmon
# /wiki/Lortel_Archives
# /wiki/Stacy_Keach
# /wiki/Michael_Strobl
# /wiki/Colin_Firth
# /wiki/Barry_Levinson
# /wiki/Michael_Strobl
# /wiki/Matthew_Vaughn
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Andrew_Lincoln
# /wiki/Tim_Robbins
# /wiki/Jack_Nicholson
# /wiki/Apollo_13_(film)
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyle_Chandler
# /wiki/Pyrates
# /wiki/Christopher_Reeve
# /wiki/Primetime_Emmy_Award
# /wiki/Al_Pacino
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Paul_Erd%C5%91s
# /wiki/Raul_Julia
# /wiki/Tremors_(film)
# /wiki/Kevin_Costner
# /wiki/Al_Pacino
# /wiki/Bill_Nighy
# /wiki/Footloose_(1984_film)
# /wiki/Holly_Near
# /wiki/The_Big_Picture_(1989_film)
# /wiki/The_River_Wild
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/Frost/Nixon_(film)
# /wiki/Internet_Broadway_Database
# /wiki/Bravo_Otto
# /wiki/Apollo_13_(film)
# /wiki/Diner_(film)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-97ddef7772e4> in <module>()
#       8   newArticle = links[random.randint(0,len(links)-1)].attrs["href"]
#       9   print(newArticle)
# ---> 10   link = getLinks(newArticle)
#
# <ipython-input-10-97ddef7772e4> in getLinks(articleUrl)
#       1 random.seed(datetime.datetime.now())
#       2 def getLinks(articleUrl):
# ----> 3   html = urlopen("http://en.wikipedia.org"+articleUrl)
#       4   bsObj = BeautifulSoup(html)
#       5   return bsObj.find("div",{"id":"bodyContent"}).findAll("a",href = re.compile("^(/wiki/)((?!:).)*$"))
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# /usr/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1252                 encode_chunked=False):
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#    1256     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1298             # default charset of iso-8859-1.
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#    1302     def getresponse(self):
#
# /usr/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1247         else:
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#    1251     def request(self, method, url, body=None, headers={}, *,
#
# /usr/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1034         msg = b"\r\n".join(self._buffer)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#    1038         if message_body is not None:
#
# /usr/lib/python3.6/http/client.py in send(self, data)
#     972         if self.sock is None:
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#     976                 raise NotConnected()
#
# /usr/lib/python3.6/http/client.py in connect(self)
#    1405             "Connect to a host on a given (SSL) port."
#    1406
# -> 1407             super().connect()
#    1408
#    1409             if self._tunnel_host:
#
# /usr/lib/python3.6/http/client.py in connect(self)
#     944         """Connect to the host and port specified in __init__."""
#     945         self.sock = self._create_connection(
# --> 946             (self.host,self.port), self.timeout, self.source_address)
#     947         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     948
#
# /usr/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#     715             err = None
#
# KeyboardInterrupt:

# %% [markdown]
# # **Crawlin on Entire Site**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
pages = set()
def getLinks(pageUrl):
  global pages
  html = urlopen("http://en.wikipedia.org"+pageUrl)
  bsObj = BeautifulSoup(html)
  for link in bsObj.findAll("a", href = re.compile("^(/wiki/)")):
    if 'href' in link.attrs:
      if link.attrs['href'] not in pages:
        newpage = link.attrs['href']
        print(newpage)
        pages.add(newpage)
        getLinks(newpage)

getLinks("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/File:A_coloured_voting_box.svg
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# /wiki/File:People_icon_dead.svg
# /wiki/User:StevenDH
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/File:To_Commons.svg
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# /wiki/User_talk:Robert_Merkel
# /wiki/User_talk:Robert_Merkel/ancient
# /wiki/User:RjLesch
# /wiki/Des_Moines,_Iowa
# /wiki/Des_Moines_(disambiguation)
# /wiki/Des_Moines_metropolitan_area
# /wiki/Geographic_coordinate_system
# /wiki/Wikipedia:Protection_policy#pending
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Help:Talk_pages
# /wiki/Help:Template
# /wiki/Wikipedia:Template_index
# /wiki/MOS:TM
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Policies_and_guidelines#guide
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Template:Nutshell
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:WikiProject_Protected_areas
# /wiki/Wikipedia:WikiProject
# /wiki/WikiProject
# /wiki/Talk:WikiProject
# /wiki/Wikipedia:What_Wikipedia_is_not#FORUM
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:NPOV
# /wiki/Wikipedia:Describing_points_of_view
# /wiki/Wikipedia:NOTOPINION
# /wiki/Wikipedia:Glossary
# /wiki/Wikipedia:Directories_and_indexes
# /wiki/Wikipedia:DIRECTORY
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/Wikipedia:Consensus
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:WikiProject_Numismatics
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:WikiProject_Council
# /wiki/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Special:WhatLinksHere/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Talk:Atlas_Shrugged
# /wiki/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# /wiki/Special:WhatLinksHere/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# /wiki/Talk:Algeria
# /wiki/Algeria
# /wiki/Arabic_language
# /wiki/Modern_Standard_Arabic
# /wiki/Classical_Arabic
# /wiki/File:Large_Koran.jpg
# /wiki/Iran
# /wiki/Iran_(disambiguation)
# /wiki/Pahlavi_dynasty
# /wiki/File:Question_book-new.svg
# /wiki/File:Question_book-3.svg
# /wiki/User:CorbieVreccan/InfoCenter
# /wiki/User:CorbieVreccan
# /wiki/Wikipedia:Ten_Year_Society
# /wiki/File:Ten_Year_Society.svg
# /wiki/User:Scott
# /wiki/File:Ok-blue.png
# /wiki/Talk:Absa_Group_Limited/Archives/2019
# /wiki/Talk:Absa_Group_Limited
# /wiki/Absa_Group_Limited
# /wiki/Absa_Bank_Limited
# /wiki/ABSA_(disambiguation)
# /wiki/ABSA_Cargo_Airline
# /wiki/File:LATAM_Cargo_logo.svg
# /wiki/File:Latam-logo_-v_(Indigo).svg
# /wiki/LATAM_Airlines_Group
# /wiki/LATAM_(disambiguation)
# /wiki/Latin_America
# /wiki/Latin_Americans
# /wiki/Hispanic_and_Latino_Americans
# /wiki/Hispanic_and_Latino_(ethnic_categories)
# /wiki/Talk:Hispanic_and_Latino_(ethnic_categories)
# /wiki/Wikipedia:WikiProject_Latin_America
# /wiki/Wikipedia:WikiProject_Latvia
# /wiki/Flag_of_Latvia
# /wiki/List_of_flags_of_Latvia
# /wiki/Latvia
# /wiki/Latvian_language
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:CONACHIEVE
# /wiki/Help:Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:Administrators#Wheel_war
# /wiki/Wikipedia_administrators
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia:Administration
# /wiki/Wikipedia:Department_directory
# /wiki/Wikipedia:Community_portal
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Task_Center
# /wiki/Wikipedia:Maintenance
# /wiki/Wikipedia:Community_portal/Opentask
# /wiki/Wikipedia:Backlog
# /wiki/Wikipedia:Blocking_policy
# /wiki/Help:I_have_been_blocked
# /wiki/Wikipedia:Blocking_policy#Evasion_and_enforcement
# /wiki/Wikipedia:Appealing_a_block
# /wiki/Wikipedia:Article_alerts
# /wiki/Template:Article_Alerts_Navheader
# /wiki/Template_talk:Article_Alerts_Navheader
# /wiki/Template:WikiProject_Council
# /wiki/Template_talk:WikiProject_Council
# /wiki/Wikipedia_talk:WikiProject_Council
# /wiki/File:WikipediaSignpostIcon.svg
# /wiki/Special:WhatLinksHere/File:WikipediaSignpostIcon.svg
# /wiki/Wikipedia_talk:WikiProject_Elements
# /wiki/Wikipedia:WikiProject_Elements/Participants/Noticeboard/archive
# /wiki/Wikipedia:WikiProject_Elements
# /wiki/Wikipedia:WikiProject_Elements/Guidelines
# /wiki/Wikipedia:WikiProject_Elements/Templates
# /wiki/Special:RecentChangesLinked/Wikipedia:WikiProject_Elements/Templates/List_of_templates
# /wiki/Wikipedia:WikiProject_Elements/Templates/List_of_templates
# /wiki/Category:WikiProject_Elements_articles
# /wiki/Help:Category
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:WikiProject_Cats
# /wiki/Wikipedia:CATP
# /wiki/Wikipedia:WikiProject_Council/Directory
# /wiki/Wikipedia:Discord
# /wiki/Wikipedia:IRC
# /wiki/Wikipedia:FORUM
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/Portal:Kansas
# /wiki/File:Darkgreen_flag_waving.svg
# /wiki/Special:WhatLinksHere/File:Darkgreen_flag_waving.svg
# /wiki/Portal:Biology
# /wiki/Wikipedia:Featured_portals
# /wiki/Wikipedia:Village_pump_(proposals)/RfC:_Ending_the_system_of_portals
# /wiki/Wikipedia:Village_pump_(proposals)
# /wiki/Wikipedia:Village_pump_(policy)
# /wiki/Wikipedia:Village_pump_(technical)
# /wiki/Wikipedia:Village_pump_(idea_lab)
# /wiki/Wikipedia:Village_pump_(miscellaneous)
# /wiki/Wikipedia:Help_desk
# /wiki/Special:Search
# /wiki/Help:Searching
# /wiki/Help:Navigation#Using_the_search_box_to_navigate
# /wiki/Help:Introduction_to_navigating_Wikipedia
# /wiki/Help:Introduction_to_navigating_Wikipedia/2
# /wiki/Help:Introduction_to_navigating_Wikipedia/1
# /wiki/Help:Introduction_to_navigating_Wikipedia/3
# /wiki/Help:Introduction_to_navigating_Wikipedia/4
# /wiki/Help:Introduction_to_navigating_Wikipedia/5
# /wiki/Help:Introduction_to_navigating_Wikipedia/6
# /wiki/Help:Introduction
# /wiki/Special:RecentChanges
# /wiki/MediaWiki:Recentchangestext
# /wiki/MediaWiki_talk:Recentchangestext
# /wiki/File:Namespace_MediaWiki.svg
# /wiki/Special:AllMessages
# /wiki/Help:MediaWiki_namespace
# /wiki/MediaWiki
# /wiki/Wikimedia
# /wiki/Wikipedia_community
# /wiki/Wikipedia:Wikipedians
# /wiki/Wikipedia:Username_policy
# /wiki/Wikipedia:UP
# /wiki/Wikipedia:FUW
# /wiki/Wikipedia:Copyrights
# /wiki/Wikipedia:Civility
# /wiki/Wikipedia:WikiProject_Cooperation
# /wiki/Wikipedia:Co-op
# /wiki/Wikipedia:HISPAGES
# /wiki/Category:Wikipedia_project_content_guidelines
# /wiki/Wikipedia:Categorization#Non-article_and_maintenance_categories
# /wiki/Wikipedia:HotCat
# /wiki/File:HotCat.png
# /wiki/User:Brambleberry_of_RiverClan/Adoption/Missionedit
# /wiki/User:Brambleberry_of_RiverClan
# /wiki/Aaron_Loup
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Good_article_criteria
# /wiki/Wikipedia:Good_article_nominations/Instructions
# /wiki/Wikipedia:Good_article_nominations
# /wiki/Wikipedia_talk:Good_article_nominations
# /wiki/Wikipedia:WikiProject_Good_articles/GAN_Backlog_Drives/April%E2%80%93May_2020
# /wiki/Wikipedia:WikiProject_Good_articles
# /wiki/Wikipedia:GA
# /wiki/Wikipedia:Good_article_reassessment
# /wiki/Wikipedia:Good_article_nominations/Report
# /wiki/User:WugBot
# /wiki/User_talk:WugBot
# /wiki/User_talk:Wugapodes
# /wiki/User_talk:Wugapodes/Archive_1
# /wiki/Help:Archiving_a_talk_page
# /wiki/Wikipedia:Historical_archive
# /wiki/Wikipedia:Historical_archive/Refreshing_brilliant_prose
# /wiki/Wikipedia_talk:Historical_archive
# /wiki/Special:Contributions/70.225.141.61
# /wiki/Help:User_contributions
# /wiki/File:Twemoji_1f527.svg
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# /wiki/Help:Editing
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:List_of_guidelines#Editing
# /wiki/Wikipedia:List_of_policies
# /wiki/Wikipedia_talk:List_of_policies
# /wiki/File:Peacedove.svg
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# /wiki/Talk:Kashmir
# /wiki/Kashmir
# /wiki/Kashmir_(disambiguation)
# /wiki/Kashmir_Valley
# /wiki/Divisions_of_India
# /wiki/Wikipedia:Citing_sources
# /wiki/Help:Footnotes
# /wiki/Help:Citation_Style_1
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# /wiki/Wikipedia_talk:Project_namespace
# /wiki/Wikipedia:Project_namespace
# /wiki/Category:Wikipedia_guidelines
# /wiki/Wikipedia:What_is_an_article%3F
# /wiki/Wikipedia:Naming_conventions_(definite_or_indefinite_article_at_beginning_of_name)
# /wiki/Category:Wikipedia_naming_conventions
# /wiki/Category:Naming_conventions
# /wiki/Help:Categories
# /wiki/Wikipedia:FAQ/Readers
# /wiki/Wikipedia:FAQ
# /wiki/Wikipedia_talk:FAQ#Requested_move_31_March_2020
# /wiki/Wikipedia:Teahouse
# /wiki/Wikipedia:Teahouse#top
# /wiki/Wikipedia:Teahouse#skip-to-bottom-anchor
# /wiki/User:Tigraan
# /wiki/Website#mirror_site
# /wiki/List_of_Internet_top-level_domains
# /wiki/Talk:List_of_Internet_top-level_domains
# /wiki/Wikipedia:WikiProject_Computing
# /wiki/Wikipedia:COMPANY
# /wiki/Wikipedia:WikiProject_Organizations
# /wiki/Template:WikiProject_status
# /wiki/Template:WikiProject_status/doc
# /wiki/Wikipedia:Template_documentation
# /wiki/Wikipedia:Consensus#Levels_of_consensus
# /wiki/Wikipedia:WikiCon
# /wiki/File:WikiConference_USA_2014_square_logo.svg
# /wiki/Special:MyTalk
# /wiki/User:SQL
# /wiki/Wikipedia:Wikibreak#Busy
# /wiki/Humour
# /wiki/Humour_(disambiguation)
# /wiki/Humorism
# /wiki/Four_temperaments
# /wiki/The_Four_Temperaments_(ballet)
# /wiki/Four_Temperaments
# /wiki/Symphony_No._2_(Nielsen)
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup
# /wiki/File:Markup-logo.svg
# /wiki/User:Kitblake/help
# /wiki/User:Kitblake
# /wiki/Special:MyContributions
# /wiki/Special:Log/35.234.3.60
# /wiki/Help:Log
# /wiki/Help:Logging_in
# /wiki/File:WP_tutorial_en_New_user_account.ogv
# /wiki/User:Proteins
# /wiki/User:WillowW
# /wiki/File:Burning_candle_on_black_background.jpg
# /wiki/User:Medist9
# /wiki/William_Shakespeare
# /wiki/Wikipedia:Featured_articles
# /wiki/File:Cscr-featured.png
# /wiki/User:Alexia_Death
# /wiki/User_talk:Alexia_Death
# /wiki/User_talk:Alexia_Death/Archive1
# /wiki/User:Camptown
# /wiki/User_talk:Camptown/Archive_1
# /wiki/User_talk:Camptown
# /wiki/User_talk:Camptown/Archive_2
# /wiki/2007_Balad_aircraft_crash
# /wiki/File:Russian_Air_Force_Antonov_An-26_Dvurekov.jpg
# /wiki/Antonov_An-26
# /wiki/File:An-26_Ni%C2%B5_Nishava_Serbien_Marko_Stojkovic_IMG_2634-1-2.jpg
# /wiki/2005_Air_Kasai_Antonov_An-26B_crash
# /wiki/Brazzaville
# /wiki/Brazzaville_(disambiguation)
# /wiki/Republic_of_the_Congo
# /wiki/Democratic_Republic_of_the_Congo
# /wiki/French_language
# /wiki/Francophonie
# /wiki/Organisation_internationale_de_la_Francophonie
# /wiki/Geographical_distribution_of_French_speakers
# /wiki/File:Proportion_of_French_speakers_by_country_in_2014_(0-50%25_gradation).svg
# /wiki/Main_Page
# /wiki/Free_content
# /wiki/Wikipedia:Pending_changes
# /wiki/Wikipedia:PCR
# /wiki/Wikipedia:TBAN
# /wiki/Wikipedia:Spam_blacklist
# /wiki/Wikipedia:Spam-blacklist
# /wiki/Wikipedia:Spam-blacklisting
# /wiki/MediaWiki:Spam-blacklist
# /wiki/MediaWiki_talk:Spam-blacklist/log
# /wiki/MediaWiki_talk:Spam-blacklist
# /wiki/Wikipedia:Request_directory
# /wiki/Wikipedia:Meetup
# /wiki/File:Gnome_globe_content.svg
# /wiki/File:Gnome-globe.svg
# /wiki/File:Gftp.svg
# /wiki/GNOME
# /wiki/Gnome_(disambiguation)
# /wiki/Wikipedia:WikiGnome
# /wiki/Wikipedia:WikiProject_Linux
# /wiki/MOS:LINUX
# /wiki/Wikipedia_talk:Manual_of_Style/Computing
# /wiki/Wikipedia_talk:Manual_of_Style
# /wiki/Special:NewSection/Wikipedia_talk:Manual_of_Style
# /wiki/NOP
# /wiki/NOP_(code)
# /wiki/Null_function
# /wiki/Identity_function
# /wiki/Empty_function
# /wiki/Domain_of_a_function
# /wiki/Domain_(disambiguation)#Mathematics
# /wiki/Domain_of_discourse
# /wiki/Help:Maintenance_template_removal
# /wiki/Wikipedia:Responsible_tagging
# /wiki/Wikipedia:Tags
# /wiki/Wikipedia:Templates
# /wiki/Help:A_quick_guide_to_templates
# /wiki/Help:Wikitext
# /wiki/Wikitext
# /wiki/File:En-Wiki2.ogg
# /wiki/User:Dmcdevit
# /wiki/Digital_Public_Library_of_America
# /wiki/Template:Infobox_organization
# /wiki/Template:Infobox_protest_faction
# /wiki/Wikipedia:Templates_for_discussion/Log/2020_April_5#Template:Infobox_protest_faction
# /wiki/Wikipedia:Templates_for_discussion
# /wiki/Wikipedia:Miscellany_for_deletion
# /wiki/Wikipedia:Miscellany_for_deletion/Administrator_instructions
# /wiki/Wikipedia:Deletion_process
# /wiki/Wikipedia:Deletion_policy
# /wiki/Wikipedia:Disambiguation_pages
# /wiki/Help:Disambiguation
# /wiki/Wikipedia:Disambiguation
# /wiki/Wikipedia:Manual_of_Style/Disambiguation_pages
# /wiki/Wikipedia_talk:Manual_of_Style/Disambiguation_pages
# /wiki/Wikipedia:WikiProject_Disambiguation
# /wiki/Wikipedia_talk:Disambiguation
# /wiki/Special:NewSection/Wikipedia_talk:Disambiguation
# /wiki/IP_address
# /wiki/Wikipedia:User_access_levels#Unregistered_(IP_or_not_logged_in)_users
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Requesting_copyright_permission
# /wiki/Wikipedia:User_access_levels
# /wiki/Wikipedia:Requests_for_adminship
# /wiki/Wikipedia:Requested_articles
# /wiki/Wikipedia:Recent_additions
# /wiki/Wikipedia:DYKNA
# /wiki/Template_talk:Did_you_know
# /wiki/Wikipedia:Did_you_know
# /wiki/Template_talk:Did_you_know#Instructions_for_nominators
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2314d312445a> in <module>()
#      15         getLinks(newpage)
#      16
# ---> 17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
# ...
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#      13         print(newpage)
#      14         pages.add(newpage)
# ---> 15         getLinks(newpage)
#      16
#      17 getLinks("")
#
# <ipython-input-11-2314d312445a> in getLinks(pageUrl)
#       5 def getLinks(pageUrl):
#       6   global pages
# ----> 7   html = urlopen("http://en.wikipedia.org"+pageUrl)
#       8   bsObj = BeautifulSoup(html)
#       9   for link in bsObj.findAll("a", href = re.compile("^(/wiki/)")):
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # **Collecting Data Accross an Entire Site**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
  global pages
  html = urlopen("http://en.wikipedia.org"+pageUrl)
  bsObj = BeautifulSoup(html)
  try:
    print(bsObj.h1.get_text())
    print(bsObj.find(id="mw-content-text").findAll("p")[0])
    print(bsObj.find(id="ca-edit").find("span").find("a").attrs['href'])
  except AttributeError:
    print("This page is missing something! No worries though!")
  for link in bsObj.findAll("a",href =re.compile("^(/wiki/)")):
    if 'href' in link.attrs:
      if link.attrs['href'] not in pages:
        newPage = link.attrs['href']
        print("---------\n"+newPage)
        pages.add(newPage)
        getLinks(newPage)
getLinks("")
# Out:
# Main Page
# <p><b><a href="/wiki/April_8" title="April 8">April 8</a></b>: <b><a href="/wiki/Mid-Sha%27ban" title="Mid-Sha'ban">Mid-Sha'ban</a></b> (Islam, 2020); <b><a href="/wiki/Fast_of_the_Firstborn" title="Fast of the Firstborn">Fast of the Firstborn</a></b> (Judaism, 2020)
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia
# Wikipedia
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy#semi
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Requests_for_page_protection
# Wikipedia:Requests for page protection
# <p>This page is for requesting that a page, file or template be <strong>fully protected</strong>, <strong>create protected</strong> (<a href="/wiki/Wikipedia:Protection_policy#Creation_protection" title="Wikipedia:Protection policy">salted</a>), <strong>extended confirmed protected</strong>, <strong>semi-protected</strong>, added to <strong>pending changes</strong>, <strong>move-protected</strong>, <strong>template protected</strong>, <strong>upload protected</strong> (file-specific), or <strong>unprotected</strong>. Please read up on the <a href="/wiki/Wikipedia:Protection_policy" title="Wikipedia:Protection policy">protection policy</a>. Full protection is used to stop edit warring between multiple users or to prevent vandalism to <a href="/wiki/Wikipedia:High-risk_templates" title="Wikipedia:High-risk templates">high-risk templates</a>; semi-protection and pending changes are usually used only to prevent IP and new user vandalism (see the <a href="/wiki/Wikipedia:Rough_guide_to_semi-protection" title="Wikipedia:Rough guide to semi-protection">rough guide to semi-protection</a>); and move protection is used to stop <a href="/wiki/Wikipedia:Page-move_war" title="Wikipedia:Page-move war">page-move wars</a>. Extended confirmed protection is used where semi-protection has proved insufficient (see the <a href="/wiki/Wikipedia:Rough_guide_to_extended_confirmed_protection" title="Wikipedia:Rough guide to extended confirmed protection">rough guide to extended confirmed protection</a>)
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy#move
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Lists_of_protected_pages
# Wikipedia:Lists of protected pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Perennial_proposals
# Wikipedia:Perennial proposals
# <p>This is a list of things that have frequently been proposed on Wikipedia, and have been <a class="mw-redirect" href="/wiki/Wikipedia:Rejected_proposals" title="Wikipedia:Rejected proposals">rejected by the community</a> several times in the past. It should be noted that merely listing something on this page does not mean it will never happen, but that it has been discussed before and never met consensus.  <a class="mw-redirect" href="/wiki/Wikipedia:Consensus_can_change" title="Wikipedia:Consensus can change">Consensus can change</a>, and some proposals that remained on this page for a long time have finally been proposed in a way that reached consensus, but you should address rebuttals raised in the past if you make a proposal along these lines.  If you feel you would still like to do one of these proposals, then raise it at the <a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Village pump">Wikipedia:Village pump</a>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# Wikipedia:Reliable sources/Perennial sources
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Reliable_sources
# Wikipedia:Reliable sources
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Reliability
# Wikipedia:WikiProject Reliability
# <p>Hello, and welcome to <b>WikiProject Reliability</b>. This WikiProject is dedicated to improving the <a class="mw-redirect" href="/wiki/Wikipedia:RS" title="Wikipedia:RS">reliability</a> of Wikipedia articles. We ensure that articles are supported by <a class="mw-redirect" href="/wiki/Wikipedia:RS" title="Wikipedia:RS">reliable sources</a>, answer inquiries on the <a class="mw-redirect" href="/wiki/Wikipedia:RSN" title="Wikipedia:RSN">reliable sources noticeboard</a>, and maintain a <a class="mw-redirect" href="/wiki/Wikipedia:RSP" title="Wikipedia:RSP">list of frequently discussed sources</a>. This project works to achieve the goals of the <a class="mw-redirect" href="/wiki/Wikipedia:V" title="Wikipedia:V">verifiability</a> and <a class="mw-redirect" href="/wiki/Wikipedia:OR" title="Wikipedia:OR">no original research</a> policies. If you would like to help, please <a href="#Participants">join</a> the project, participate on the <a href="/wiki/Wikipedia_talk:WikiProject_Reliability" title="Wikipedia talk:WikiProject Reliability">talk page</a> and see the <a href="#Open_tasks">open tasks</a> below.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WRE
# Wikipedia:WikiProject Resource Exchange
# <p><b>Shortcuts</b>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:People_icon.svg
# File:People icon.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/3/37/People_icon.svg" title="People icon.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 22 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# Pages that link to "File:People icon.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:People_icon.svg" title="File:People icon.svg">File:People icon.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Help:What_links_here
# Help:What links here
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# Wikipedia:Project namespace
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Policies_and_guidelines
# Wikipedia:Policies and guidelines
# <p>Wikipedia's <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Politics
# Wikipedia:WikiProject Politics
# <p>Welcome to <b>WikiProject Politics</b>. A <a href="/wiki/Wikipedia:WikiProject" title="Wikipedia:WikiProject">WikiProject</a> is a group of pages in the "Wikipedia" <a href="/wiki/Wikipedia:Namespace" title="Wikipedia:Namespace">article namespace</a> that are devoted to the management of a specific topic or family of topics within Wikipedia; and, simultaneously, a <a href="/wiki/Wikipedia:WikiProject_Politics/Participants" title="Wikipedia:WikiProject Politics/Participants">group of editors</a> who use those pages to collaborate on encyclopedic work. It is not a place to write encyclopedia articles directly, but a resource to help coordinate and organize the writing and editing of those articles. This group focuses on articles in the broad field of <a href="/wiki/Politics" title="Politics">Politics</a>.  This page and its subpages contain their suggestions; it is hoped that this project will help to focus the efforts of other Wikipedians. You may sign up for the project on the <a href="/wiki/Wikipedia:WikiProject_Politics/Participants" title="Wikipedia:WikiProject Politics/Participants">Participants</a> list below.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:A_coloured_voting_box.svg
# File:A coloured voting box.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/0/01/A_coloured_voting_box.svg" title="A coloured voting box.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 160 × 160 pixels, file size: 11 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy#full
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# Wikipedia:WikiProject Parliamentary Procedure
# <p><b>WikiProject Parliamentary Procedure</b> is devoted to improving the quality and comprehensiveness of articles on topics related to <a href="/wiki/Parliamentary_procedure" title="Parliamentary procedure">parliamentary procedure</a>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:People_icon_dead.svg
# File:People icon dead.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/6/6b/People_icon_dead.svg" title="People icon dead.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 24 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/User:StevenDH
# User:StevenDH
# <p><br/>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:User_pages
# Wikipedia:User pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy#extended
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Party_and_person
# Wikipedia:Party and person
# <p>Different content policies and guidelines use slightly different standards.  One of the commonly misunderstood distinctions is between "secondary source" and "third party".
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:Essay.svg
# File:Essay.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/7e/Essay.svg" title="Essay.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 35 × 42 pixels, file size: 17 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:Essay.png
# File:Wikipedia Essay icon.png
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/2/2d/Wikipedia_Essay_icon.png" title="Wikipedia Essay icon.png">Wikipedia_Essay_icon.png</a> ‎<span class="fileInfo">(30 × 35 pixels, file size: 2 KB, MIME type: <span class="mime-type">image/png</span>)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:To_Commons.svg
# File:To Commons.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/78/To_Commons.svg" title="To Commons.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 913 × 913 pixels, file size: 200 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# Pages that link to "File:To Commons.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:To_Commons.svg" title="File:To Commons.svg">File:To Commons.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/User_talk:Robert_Merkel
# User talk:Robert Merkel
# <p><a href="/wiki/User_talk:Robert_Merkel/ancient" title="User talk:Robert Merkel/ancient">User talk:Robert Merkel/ancient</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_1" title="User talk:Robert Merkel/archive 1">User talk:Robert Merkel/archive 1</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_2" title="User talk:Robert Merkel/archive 2">User talk:Robert Merkel/archive 2</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_3" title="User talk:Robert Merkel/archive 3">User talk:Robert Merkel/archive 3</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_4" title="User talk:Robert Merkel/archive 4">User talk:Robert Merkel/archive 4</a>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/User_talk:Robert_Merkel/ancient
# User talk:Robert Merkel/ancient
# <p>Did you write the Bradman article?  If so, good work.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/User:RjLesch
# User:RjLesch
# <p>Database developer and project manager, <a href="/wiki/Des_Moines,_Iowa" title="Des Moines, Iowa">Des Moines, Iowa</a>, <a class="mw-redirect" href="/wiki/United_States_of_America" title="United States of America">United States of America</a>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Des_Moines,_Iowa
# Des Moines, Iowa
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Des_Moines_(disambiguation)
# Des Moines (disambiguation)
# <p><b><a href="/wiki/Des_Moines,_Iowa" title="Des Moines, Iowa">Des Moines</a></b> is the capital of the state of Iowa in the United States.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Des_Moines_metropolitan_area
# Des Moines metropolitan area
# <p>
# <span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Des_Moines_metropolitan_area&amp;params=41.555147_N_93.835831_W_type:adm2nd"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">41°33′19″N</span> <span class="longitude">93°50′09″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">41.555147°N 93.835831°W</span><span style="display:none">﻿ / <span class="geo">41.555147; -93.835831</span></span></span></a></span></span></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Geographic_coordinate_system
# Geographic coordinate system
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy#pending
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Child_protection
# Wikipedia:Child protection
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Biographies_of_living_persons
# Wikipedia:Biographies of living persons
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# Wikipedia:Biographies of living persons/Noticeboard
# <p>This page is for reporting issues regarding <b><a href="/wiki/Wikipedia:Biographies_of_living_persons" title="Wikipedia:Biographies of living persons">biographies of living persons</a></b>. Generally this means cases where editors are repeatedly adding defamatory or libelous material to articles about living people over an extended period.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Template:Noticeboard_links
# Template:Noticeboard links
# <p><code>{{Noticeboard links |state=uncollapsed |nostb=yes}}</code>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Template_talk:Noticeboard_links
# Template talk:Noticeboard links
# <p>The result of the move request was <b>moved to <a href="/wiki/Template:Noticeboard_links" title="Template:Noticeboard links">Template:Noticeboard links</a>.</b> –<b><a href="/wiki/User:Juliancolton" title="User:Juliancolton"><span style="font-family:Script MT;color:#36648B">Juliancolton</span></a></b> | <a href="/wiki/User_talk:Juliancolton" title="User talk:Juliancolton"><sup><span style="font-family:Verdana;color:gray"><i>Talk</i></span></sup></a> 00:21, 6 September 2009 (UTC)
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Talk_page_guidelines
# Wikipedia:Talk page guidelines
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Help:Talk_pages
# Help:Talk pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Help:Template
# Help:Template
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Template_index
# Wikipedia:Template index
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/MOS:TM
# Wikipedia:Manual of Style/Trademarks
# <p><b><a href="/wiki/Trademark" title="Trademark">Trademarks</a></b> include words and short phrases used by legal entities to identify themselves and their products and services. Often, these names are written in several ways with variations in capitalization, punctuation, and formatting. The advice in this page also applies to names and phrases used to identify individuals, movements, groups, forums, projects, events, and other non-commercial entities and their output.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Manual_of_Style
# Wikipedia:Manual of Style
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Policies_and_guidelines#guide
# Wikipedia:Policies and guidelines
# <p>Wikipedia's <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:List_of_policies#Procedural
# Wikipedia:List of policies
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Template:Nutshell
# Template:Nutshell
# <p>This template presents a <a class="mw-redirect" href="/wiki/Wikipedia:TRITE" title="Wikipedia:TRITE">concise</a> summary at the top of  <a href="/wiki/Wikipedia:Administration#Data_structure_and_development" title="Wikipedia:Administration">administration pages</a>. It is placed below the title and other infoboxes and above the first paragraph of the main body.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Protection_policy#template
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Protected_areas
# Wikipedia:WikiProject Protected areas
# <p>This <a href="/wiki/Wikipedia:WikiProject" title="Wikipedia:WikiProject">WikiProject</a> aims primarily to provide information on all <b><a href="/wiki/Protected_area" title="Protected area">protected areas</a></b> (abbreviated on this page as <b>PAs</b>) in the world.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject
# Wikipedia:WikiProject
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/WikiProject
# WikiProject
# <p>A <b>WikiProject</b>, or <b>Wikiproject</b>, is the organization of a group of participants in a wiki established in order to achieve specific editing goals, or to achieve goals relating to a specific field of knowledge. WikiProjects are prevalent within the largest wiki, Wikipedia, and exist to varying degrees within sister projects such as <a href="/wiki/Wiktionary" title="Wiktionary">Wiktionary</a>, <a href="/wiki/Wikiquote" title="Wikiquote">Wikiquote</a>, <a href="/wiki/Wikidata" title="Wikidata">Wikidata</a> and <a href="/wiki/Wikisource" title="Wikisource">Wikisource</a>. They also exist in different languages, and translation of articles is a form of their collaboration.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Talk:WikiProject
# Talk:WikiProject
# <p>To fill out this checklist, please <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Talk:WikiProject&amp;action=edit">add</a> the following code to the template call:
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:What_Wikipedia_is_not#FORUM
# Wikipedia:What Wikipedia is not
# <p><a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> is an online <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a> and, as a means to that end, an <a class="extiw" href="https://meta.wikimedia.org/wiki/The_Wikipedia_Community" title="meta:The Wikipedia Community">online community</a> of individuals interested in building and using a high-quality encyclopedia in a spirit of mutual respect. Therefore, <b>there are certain things that Wikipedia is <em>not</em></b>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Notability
# Wikipedia:Notability
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:NPOV
# Wikipedia:Neutral point of view
# <p>All encyclopedic content on <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> must be written from a <b>neutral point of view</b> (<b>NPOV</b>), which means representing fairly, proportionately, and, as far as possible, without editorial bias, all the significant <a href="/wiki/Point_of_view_(philosophy)" title="Point of view (philosophy)">views</a> that have been <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">published by reliable sources</a> on a topic.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Describing_points_of_view
# Wikipedia:Describing points of view
# <p>At Wikipedia, <b>points of view</b> (<b>POVs</b>) – <a class="mw-redirect" href="/wiki/Perspective_(cognitive)" title="Perspective (cognitive)">cognitive perspectives</a> – are often essential to articles which treat controversial subjects. Wikipedia's official "<a class="mw-redirect" href="/wiki/Wikipedia:NPOV" title="Wikipedia:NPOV">Neutral Point of View</a>" (NPOV) policy does not mean that all the POVs of all the Wikipedia editors have to be represented. Rather, the article should represent the POVs of the main scholars and specialists who have produced reliable sources on the issue.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:NOTOPINION
# Wikipedia:What Wikipedia is not
# <p><a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> is an online <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a> and, as a means to that end, an <a class="extiw" href="https://meta.wikimedia.org/wiki/The_Wikipedia_Community" title="meta:The Wikipedia Community">online community</a> of individuals interested in building and using a high-quality encyclopedia in a spirit of mutual respect. Therefore, <b>there are certain things that Wikipedia is <em>not</em></b>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Glossary
# Wikipedia:Glossary
# <p>This is a <b><a href="/wiki/Glossary" title="Glossary">glossary</a> of terms commonly used on <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></b>. For a shorter and simpler glossary aimed at readers rather than editors, see <a href="/wiki/Help:Glossary" title="Help:Glossary">Help:Glossary</a>.
# <br/>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Directories_and_indexes
# Wikipedia:Directories and indexes
# <p>The following is a list of <b>Wikipedia's directories and indexes</b>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:DIRECTORY
# Wikipedia:What Wikipedia is not
# <p><a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> is an online <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a> and, as a means to that end, an <a class="extiw" href="https://meta.wikimedia.org/wiki/The_Wikipedia_Community" title="meta:The Wikipedia Community">online community</a> of individuals interested in building and using a high-quality encyclopedia in a spirit of mutual respect. Therefore, <b>there are certain things that Wikipedia is <em>not</em></b>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# Wikipedia:What "Ignore all rules" means
# <p><br/>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Ignore_all_rules
# Wikipedia:Ignore all rules
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Consensus
# Wikipedia:Consensus
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Conflict_of_interest
# Wikipedia:Conflict of interest
# <p><b>Conflict of interest</b> (<b>COI</b>) <b>editing</b> involves contributing to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> about yourself, family, friends, clients, employers, or your financial and other relationships. Any <a href="#What_is_conflict_of_interest?">external relationship</a> can trigger a <a href="/wiki/Conflict_of_interest" title="Conflict of interest">conflict of interest</a>. That someone has a conflict of interest is a description of a situation, not a judgement about that person's opinions, integrity, or <a class="mw-redirect" href="/wiki/Wikipedia:GOODFAITH" title="Wikipedia:GOODFAITH">good faith</a>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# Wikipedia:Conflict of interest/Noticeboard
# <p><span></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Numismatics
# Wikipedia:WikiProject Numismatics
# <p><b>Numismatics</b> (ancient <a href="/wiki/Greek_language" title="Greek language">Greek</a>: <b><span lang="grc" title="Ancient Greek language text">νομισματική</span></b>) is the scientific study of <a href="/wiki/Money" title="Money">money</a> and its <a href="/wiki/History_of_money" title="History of money">history</a> in all its varied forms. While numismatists are often characterized as studying <a href="/wiki/Coin" title="Coin">coins</a>, the discipline also includes the study of <a class="mw-redirect" href="/wiki/Banknotes" title="Banknotes">banknotes</a> (<a href="/wiki/Notaphily" title="Notaphily">notaphily</a>), stock certificates (<a href="/wiki/Scripophily" title="Scripophily">scripophily</a>), <a href="/wiki/Medal" title="Medal">medals</a>, medallions, and <a href="/wiki/Token_coin" title="Token coin">token coins</a> (also referred to as <a href="/wiki/Exonumia" title="Exonumia">exonumia</a>).
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Council/Guide
# Wikipedia:WikiProject Council/Guide
# <p>A <b>WikiProject</b> is a group of people who want to work as a team to improve Wikipedia. This <a href="/wiki/Wikipedia:Policies_and_guidelines" title="Wikipedia:Policies and guidelines">guideline</a> outlines the accepted practices for starting and maintaining WikiProjects, as well as some tips for how to organize WikiProjects effectively. For more detailed instructions on how to start a WikiProject, see <a href="/wiki/Wikipedia:WikiProject_Council/Guide/WikiProject" title="Wikipedia:WikiProject Council/Guide/WikiProject">Wikipedia:WikiProject Council/Guide/WikiProject</a>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Wikipedia:WikiProject_Council
# Wikipedia:WikiProject Council
# <p>The <b>WikiProject Council</b> is a group of Wikipedians that encourage and assist with the development of WikiProjects. The council acts as a central point for inter-WikiProject discussion and collaboration. New to WikiProjects? See <a href="/wiki/Wikipedia:Wikipedia_Signpost/2013-04-01/WikiProject_report" title="Wikipedia:Wikipedia Signpost/2013-04-01/WikiProject report">FAQs about WikiProjects</a> for the answers to the most common inquiries. The <a href="/wiki/Wikipedia:WikiProject_Council/Guide" title="Wikipedia:WikiProject Council/Guide">WikiProject guideline page</a> outlines generally accepted protocols and conventions.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:WikiProject_Council_with_transparent_background.svg
# File:WikiProject Council with transparent background.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/b/bd/WikiProject_Council_with_transparent_background.svg" title="WikiProject Council with transparent background.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 512 × 459 pixels, file size: 4 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Special:WhatLinksHere/File:WikiProject_Council_with_transparent_background.svg
# Pages that link to "File:WikiProject Council with transparent background.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:WikiProject_Council_with_transparent_background.svg" title="File:WikiProject Council with transparent background.svg">File:WikiProject Council with transparent background.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Talk:Atlas_Shrugged
# Talk:Atlas Shrugged
# <p><span></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# File:Círculos Concéntricos.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/1/13/C%C3%ADrculos_Conc%C3%A9ntricos.svg" title="Círculos Concéntricos.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 336 × 336 pixels, file size: 376 bytes)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Special:WhatLinksHere/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# Pages that link to "File:Círculos Concéntricos.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg" title="File:Círculos Concéntricos.svg">File:Círculos Concéntricos.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Talk:Algeria
# Talk:Algeria
# <p>To fill out this checklist, please <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Talk:Algeria&amp;action=edit">add</a> the following code to the template call:
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Algeria
# Algeria
# <p>
# <span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Algeria&amp;params=28_N_2_E_scale:10000000_type:country_region:DZ"><span class="geo-default"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">28°N</span> <span class="longitude">2°E</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-nondefault"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">28°N 2°E</span><span style="display:none">﻿ / <span class="geo">28; 2</span></span></span></a></span></span></span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Arabic_language
# Arabic
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Modern_Standard_Arabic
# Modern Standard Arabic
# <p><b>Modern Standard Arabic</b> (<b>MSA</b>), or <b>Modern Written Arabic</b> (shortened to <b>MWA</b>),<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[4]</a></sup> is a term used mostly by Western linguists<sup class="reference" id="cite_ref-:0_8-0"><a href="#cite_note-:0-8">[5]</a></sup> to refer to the variety of <a href="/wiki/Standard_language" title="Standard language">standardized</a>, <a href="/wiki/Literary_language" title="Literary language">literary</a> <a href="/wiki/Arabic" title="Arabic">Arabic</a> that developed in the <a href="/wiki/Arab_world" title="Arab world">Arab world</a> in the late 19th and early 20th centuries. While it is the language used in books, newspapers, and academic settings, Modern Standard Arabic is generally not spoken as a <a class="mw-redirect" href="/wiki/Mother_tongue" title="Mother tongue">mother tongue</a>, like <a href="/wiki/Classical_Latin" title="Classical Latin">Classical Latin</a> or <i>Soutenu</i> French.<sup class="reference" id="cite_ref-:0_8-1"><a href="#cite_note-:0-8">[5]</a></sup> MSA is a <a href="/wiki/Pluricentric_language" title="Pluricentric language">pluricentric</a> standard language taught throughout the Arab world in <a class="mw-redirect" href="/wiki/Formal_education" title="Formal education">formal education</a>. It differs significantly from many <a href="/wiki/Vernacular" title="Vernacular">vernacular</a> <a href="/wiki/Varieties_of_Arabic" title="Varieties of Arabic">varieties of Arabic</a> that are commonly spoken as mother tongues in the area; these are only partially mutually intelligible with both MSA and with each other depending on their proximity in the <a href="/wiki/Dialect_continuum#Arabic" title="Dialect continuum">Arabic</a> <a href="/wiki/Dialect_continuum" title="Dialect continuum">dialect continuum</a>.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Classical_Arabic
# Classical Arabic
# <p><b>Classical Arabic</b> (Arabic: <span dir="rtl" lang="ar">اَلعَرَبِيَّةُ ٱلْفُصْحَىٰ</span>‎, <i><i lang="ar-Latn" title="Arabic-language romanization">al-ʿarabiyyah al-fuṣḥā</i></i>) is the form of the <a class="mw-redirect" href="/wiki/Arabic_language" title="Arabic language">Arabic language</a> used in <a href="/wiki/Umayyad_Caliphate" title="Umayyad Caliphate">Umayyad</a> and <a href="/wiki/Abbasid_Caliphate" title="Abbasid Caliphate">Abbasid</a> literary texts from the 7th to the 9th century AD.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:Large_Koran.jpg
# File:Large Koran.jpg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/a/ae/Large_Koran.jpg" title="Large Koran.jpg">Original file</a> ‎<span class="fileInfo">(966 × 1,500 pixels, file size: 1.15 MB, MIME type: <span class="mime-type">image/jpeg</span>)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Iran
# Iran
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Iran_(disambiguation)
# Iran (disambiguation)
# <p><b><a href="/wiki/Iran" title="Iran">Iran</a></b>, officially the Islamic Republic of Iran, is a country in Southern and Western Asia.
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/Pahlavi_dynasty
# Pahlavi dynasty
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:Question_book-new.svg
# File:Question book-new.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/9/99/Question_book-new.svg" title="Question book-new.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 512 × 399 pixels, file size: 6 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/File:Question_book-3.svg
# File:Question book-3.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/e/e3/Question_book-3.svg" title="Question book-3.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 252 × 199 pixels, file size: 25 KB)</span>
# </p>
# This page is missing something! No worries though!
# ---------
# /wiki/User:CorbieVreccan/InfoCenter
# User:CorbieVreccan/InfoCenter
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-c8f4a1ac6411> in <module>()
#      21         pages.add(newPage)
#      22         getLinks(newPage)
# ---> 23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      20         print("---------\n"+newPage)
#      21         pages.add(newPage)
# ---> 22         getLinks(newPage)
#      23 getLinks("")
#
# <ipython-input-13-c8f4a1ac6411> in getLinks(pageUrl)
#      10   try:
#      11     print(bsObj.h1.get_text())
# ---> 12     print(bsObj.find(id="mw-content-text").findAll("p")[0])
#      13     print(bsObj.find(id="ca-edit").find("span").find("a").attrs['href'])
#      14   except AttributeError:
#
# IndexError: list index out of range

# %% [markdown]
# # **Crwaling Across the Internet**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random
pages = set()
random.seed(datetime.datetime.now())

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl):
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bs = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        internalLinks = getInternalLinks(bs, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,
                                    len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('http://oreilly.com')
# Out:
# Random external link is: https://www.facebook.com/OReilly/
# Random external link is: http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-eyJuYW1lIjoiTydSZWlsbHkgTWVkaWEiLCJhZGRyZXNzIjoiMTAwNSBHcmF2ZW5zdGVpbiBId3kgTiwgU2ViYXN0b3BvbCwgQ2FsaWZvcm5pYSIsImxhdGl0dWRlIjozOC40MTE0NTUxNjI4ODEsImxvbmdpdHVkZSI6LTEyMi44NDA5NDQ3MjYxMiwicHJvdmlkZXJOYW1lIjoiZmFjZWJvb2siLCJwcm92aWRlcklkIjoxNTEzNzUwMDQzMH0%3D%3Flink%3Daddresses%26fb_locale%3Den_US%26ref%3Dfacebook&h=AT3niaxJKnVoQGMwcT3vLc9irc9jBRBsz5MiOnzBONPtspJJHleAp3OOLAaWNNEh15SaN9vmWs9Pu5-XJGVTmST0GHjoNMf5DHTy3UOCcnruLe3UGhfxbU2TDiKfMRfLZ9qu26jg7mbDNyT6
# No external links, looking around the site for one
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e054264bd28f> in <module>()
#      53     followExternalOnly(externalLink)
#      54
# ---> 55 followExternalOnly('http://oreilly.com')
#
# <ipython-input-17-e054264bd28f> in followExternalOnly(startingSite)
#      51     externalLink = getRandomExternalLink(startingSite)
#      52     print('Random external link is: {}'.format(externalLink))
# ---> 53     followExternalOnly(externalLink)
#      54
#      55 followExternalOnly('http://oreilly.com')
#
# <ipython-input-17-e054264bd28f> in followExternalOnly(startingSite)
#      51     externalLink = getRandomExternalLink(startingSite)
#      52     print('Random external link is: {}'.format(externalLink))
# ---> 53     followExternalOnly(externalLink)
#      54
#      55 followExternalOnly('http://oreilly.com')
#
# <ipython-input-17-e054264bd28f> in followExternalOnly(startingSite)
#      49
#      50 def followExternalOnly(startingSite):
# ---> 51     externalLink = getRandomExternalLink(startingSite)
#      52     print('Random external link is: {}'.format(externalLink))
#      53     followExternalOnly(externalLink)
#
# <ipython-input-17-e054264bd28f> in getRandomExternalLink(startingPage)
#      44         internalLinks = getInternalLinks(bs, domain)
#      45         return getRandomExternalLink(internalLinks[random.randint(0,
# ---> 46                                     len(internalLinks)-1)])
#      47     else:
#      48         return externalLinks[random.randint(0, len(externalLinks)-1)]
#
# /usr/lib/python3.6/random.py in randint(self, a, b)
#     219         """
#     220
# --> 221         return self.randrange(a, b+1)
#     222
#     223     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# /usr/lib/python3.6/random.py in randrange(self, start, stop, step, _int)
#     197             return istart + self._randbelow(width)
#     198         if step == 1:
# --> 199             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#     200
#     201         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (0,0, 0)

# %% [markdown]
# # **Collect all External Links from a Site**

# %%
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('http://oreilly.com')
getAllExternalLinks('http://oreilly.com')
# Out:
# https://www.oreilly.com/conferences/from-laura-baldwin.html
# https://www.oreilly.com
# https://www.oreilly.com/online-learning/enterprise.html
# https://www.oreilly.com/sign-in.html
# https://www.oreilly.com/online-learning/try-now.html
# https://www.oreilly.com/online-learning/index.html
# https://www.oreilly.com/online-learning/individuals.html
# https://www.oreilly.com/online-learning/teams.html
# https://www.oreilly.com/online-learning/government.html
# https://www.oreilly.com/online-learning/academic.html
# https://www.oreilly.com/online-learning/features.html
# https://www.oreilly.com/online-learning/custom-services.html
# https://www.oreilly.com/online-learning/pricing.html
# https://www.oreilly.com/whats-new.html
# https://www.oreilly.com/online-learning/certifications.html
# https://learning.oreilly.com/interactive/
# https://www.oreilly.com/online-learning/government-free-access.html
# https://www.oreilly.com/online-learning/navigate-change/nb.html
# https://learning.oreilly.com/register/
# https://learning.oreilly.com/team-setup/
# https://www.oreilly.com/about/approach.html
# http://shop.oreilly.com/category/customer-service.do
# https://twitter.com/oreillymedia
# https://www.facebook.com/OReilly/
# https://www.linkedin.com/company/oreilly-media
# https://www.youtube.com/user/OreillyMedia
# https://www.oreilly.com/emails/newsletters/
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://www.oreilly.com/about/history.html
# https://www.oreilly.com/tim/
# https://www.oreilly.com/pub/pr/3298
# https://www.oreilly.com/pub/pr/3297
# https://www.oreilly.com/pub/pr/3296
# https://www.oreilly.com/press/
# https://www.oreilly.com/about/editorial_independence.html
# https://www.oreilly.com/about/resources.html
# https://cdn.oreillystatic.com/pdf/Online_Training_Proposal_Form.pdf
# https://www.oreilly.com/conferences/speak.html
# https://cdn.oreillystatic.com/pdf/Book_Proposal_Form.pdf
# https://www.oreilly.com/careers/
# https://www.oreilly.com/partner/optimize-your-community-partnership.html
# https://app.oreilly.com/cs/user/login?x-redirect=http://www.oreilly.com/partner/signup.csp
# https://conferences.oreilly.com
# https://oreilly.com/online-learning/enterprise.html
# https://www.oreilly.com/oreilly/privacy.html
# https://www.oreilly.com/online-learning/testimonials.html
# https://www.oreilly.com/online-learning/insights-dashboard.html
# https://www.oreilly.com/privacy.html
# https://cdn.oreillystatic.com/pdf/OReilly_Capabilities_Statement.pdf
# https://www.gsaelibrary.gsa.gov/ElibMain/contractorInfo.do?contractNumber=47QTCA19D0022&contractorName=O%27REILLY+MEDIA%2C+INC&executeQuery=YES
# https://www.oreilly.com/academic/
# https://go.proquest.com/PQ_OReilly/
# http://go.proquest.com/SafariHigherEd
# https://www.oreilly.com/about/
# http://www.oreilly.com
# http://www.oreilly.com/about/sebastopol_directions.html
# http://www.oreilly.com/about/boston_directions.html
# http://www.oreilly.com.cn/
# http://www.oreilly.co.jp
# https://www.oreilly.com/terms/
# https://learning.oreilly.com/membership-agreement/
# https://www.safaribooksonline.com/membership-agreement/
# https://www.safaribooksonline.com/terms/
# https://feedback-form.truste.com/watchdog/request
# https://www.oreilly.com/privacy-cookies.html
# https://www.oreilly.com/conferences/code-of-conduct.html
# https://www.oreilly.com/privacy-categories-disclosed-for-business-purpose.html
# https://www.oreilly.com/privacy-categories-disclosed-for-valuable-consideration.html
# https://www.privacyshield.gov
# https://www.privacyshield.gov/article?id=How-to-Submit-a-Complaint
# https://www.privacyshield.gov/article?id=ANNEX-I-introduction
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/adequacy-protection-personal-data-non-eu-countries_en
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/eu-us-privacy-shield_en
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/model-contracts-transfer-personal-data-third-countries_en
# https://ico.org.uk/
# https://tools.google.com/dlpage/gaoptout/
# https://smetrics.oreilly.com/optout.html?optout=1&confirm_change=1
# https://schools.safaribooksonline.com/privacy/
# https://www.oreilly.com/privacy-111219.html
# https://www.oreilly.com/privacy-081519.html
# https://www.oreilly.com/privacy-112118.html
# https://www.oreilly.com/privacy-101018.html
# https://www.oreilly.com/privacy-100418.html
# https://www.oreilly.com/privacy-052518.html
# https://www.oreilly.com/privacy-111016.html
# https://www.oreilly.com/privacy-120214.html
# https://www.oreilly.com/privacy-091415.html
# http://archive.oreilly.com/oreillyschool/privacy-policy/
# http://archive.oreilly.com/oreillyschool/privacy-policy-version2/
# https://cdn.oreillystatic.com/pdf/SafariPrivacyPolicy_v3.4_23October2017.pdf
# https://www.safaribooksonline.com/static/legal/SafariPrivacyPolicy_v3.3_13June2017.a4d9478408f5.pdf
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-19-15191682ba13> in <module>()
#      22
#      23 allIntLinks.add('http://oreilly.com')
# ---> 24 getAllExternalLinks('http://oreilly.com')
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#      18         if link not in allIntLinks:
#      19             allIntLinks.add(link)
# ---> 20             getAllExternalLinks(link)
#      21
#      22
#
# <ipython-input-19-15191682ba13> in getAllExternalLinks(siteUrl)
#       4
#       5 def getAllExternalLinks(siteUrl):
# ----> 6     html = urlopen(siteUrl)
#       7     domain = '{}://{}'.format(urlparse(siteUrl).scheme,
#       8                               urlparse(siteUrl).netloc)
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found
